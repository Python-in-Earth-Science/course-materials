# %% [markdown]
# # **Assignment 3: A Year of Weather in Nashville**
#
# *YOUR NAME HERE*
#
# *DUE DATE HERE*

# %% [markdown]
# ## Assignment Overview
#
# In this assignment, you'll analyze daily weather data from Nashville, Tennessee for the year 2024. You'll practice:
# - writing functions with parameters and return values
# - loading and manipulating DataFrames
# - using loops to analyze data
# - filtering data with boolean indexing
# - creating visualizations
#
#
# **IMPORTANT:** please include text comments and description for your future self, so that when you look back you'll have notes on how you solved these problems!*
#
# **Throughout this Assignment you will create figure files. Please turn in the following figures along with your notebook:**
# - `nashville_temp_2024.png`
# - `nashville_precip_2024.png`
#
# **Graduate students please also turn in:**
# - `boulder_nashville_comparison.png`

# %% [markdown]
# ## **Quick Reference**
# ### Function Template
# ```python
# def function_name(required_param, optional_param=default):
#     """
#     Brief description.
#
#     Parameters:
#     -----------
#     required_param : type
#         Description
#     optional_param : type
#         Description (default: value)
#
#     Returns:
#     --------
#     type : Description
#     """
#     # Your code here
#     result = required_param + optional_param
#     return result
# ```
#
# ### Loop Template
# ```python
# # Initialize counters before loop
# counter = 0
#
# # Loop through rows
# for index, row in df.iterrows():
#     value = row['ColumnName']
#     if value > threshold:
#         counter += 1
# ```
#
# ### Boolean Indexing Template
# ```python
# # Filter rows where condition is True
# filtered_df = df[df['column'] > value]
#
# # Multiple conditions (use parentheses!)
# filtered_df = df[(df['col1'] > value) & (df['col2'] != -999)]
# ```

# %% [markdown]
# # **Setup Code** (Run this first!)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %% [markdown]
# # **Part 1: Reading in data and adding columns**
# *(20 pts)*<br>
#
# *The data file `nashville_weather_2024.csv` contains daily weather data for each day of the year 2024. The data include:*
#
# - Year (2024)
# - Month (1-12)
# - Day (1-31)
# - minimum temperature on that day (Tmin, in degrees Farenheit)
# - maximum temperature on that day (Tmax, in degrees Farenheit)
# - precipitation depth (Precip, in inches)
# - depth of snow that fell that day (Snow, in inches)
# - current depth of snow on the ground (Snowcover, in inches)
#
# *The "no data" code is -999.*

# %% [markdown]
# <div class="alert alert-info">
#
# **Write a function called `load_weather_data` that:**
# - takes a file name as an input parameter
# - reads the CSV file into a Pandas DataFrame
# - **Converts the Year, Month, Day columns into a single DateTime column**
#     - Hint: use `pd.to_datetime()` with a dictionary or combine the columns
# - **Adds a "DayOfYear" column** (1-366) using the `dt.dayofyear` attribute
# - **Adds a "Precip_mm" column** by converting Precip from inches to mm
#     - mm = inches * 25.4
# - returns the DataFrame
#
# **Test your function by displaying the first 10 rows to verify the new columns were added correctly.**

# %%
# YOUR CODE HERE

# %% [markdown]
# # **Part 2: Plotting temperature**
# *(15 pts)*<br>

# %% [markdown]
# <div class="alert alert-info">
#
# **Write a function called `plot_temperature` that creates a line plot of daily low and high temperatures.**
#
# **Function Requirements**:
# - **3 required parameters:**
#     - `days`: array/Series of day numbers
#     - `temp_low`: array/Series of daily low temperatures
#     - `temp_high`: array/Series of daily high temperatures
# - **1 optional parameter:**
#     - `title`: string for plot title (default: "Temperature Data")
#
# **Plot Requirements**:
# - use different colors or line styles for low vs high temperatures
# - label both axes clearly
# - display the title
# - include a legend identifying the two curves
# - add gridlines
# - **Save the figure** as `nashville_temp_2024.png` before showing it
#
# **After creating the function, test it by plotting the full year of Nashville temperature data.**

# %%
# YOUR CODE HERE

# %% [markdown]
# # **Part 3: Analyzing precipitation**
# *(20 pts)*<br>

# %% [markdown]
# <div class="alert alert-info">
#
# **Write a function called `analyze_precip` that takes your DataFrame as input and uses a *loop* to count the following.:**
# - total precipitation depth over the whole year (sum of all valid Precip values)
# - number of sunny days (Precip = 0)
# - number of snowy days (Snow > 0)
# - number of rainy days (Precip > 0 AND Snow > 0)
# - number of unknown days (either Precip or Snow equals -999)
#
# **Your function should either print the results directly, or return them so the calling code can print them (or both).**

# %% [markdown]
# **Hints**:
# - remember to loop through rows with `for index, row in df.iterrows():`
# - use `row['column_name']` to access column values
# - initialize all counters BEFORE the loop
# - use if/elif/else statements to cateogrize each day
# - you can find the number of rows with `len(df)`
#
# **Reminder:** A day counts as "sunny" if there's NO precipitation (Precip=0), not if it's just less than some threshold.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## 🎯 Quick Check: Skills Inventory
#
# Before continuing, make sure you can answer YES to these:
# - [ ] I can write a function with parameters and a return statement
# - [ ] I can loop through DataFrame rows with `for index, row in df.iterrows()`
# - [ ] I know how to initialize counters before a loop
# - [ ] I understand boolean indexing: `df[df['column'] > value]`
#
# If any are unclear, review your worksheet or ask for help!
#
# ---

# %% [markdown]
# # **Part 4: Filtering data**
# *(15 pts)*<br>
#
# There are days in the dataset where precipitation is listed as -999 (no data available). Before plotting precipitation, we need to filter out these invalid data points.

# %% [markdown]
# <div class="alert alert-info">
#
# **Write a function called `filter_valid_precipitation` that:**
# - takes your DataFrame as input
# - returns TWO arrays (or Series):
#     - valid precipitation values in mm (where Precip ≠ -999)
#     - corresponding day-of-year numbers for those valid days
#
# **After writing your function, verify tha the number of valid days matches what you found in Part 3 (total days minus unknown days)**

# %% [markdown]
# **Approach suggestion**: Use boolean indexing!

# %%
# YOUR CODE HERE

# %% [markdown]
# ### **BONUS**:
# - Try filtering for BOTH Precip ≠ -999 AND Snow ≠ -999.
# - How many days have both values valid?

# %%
# YOUR CODE HERE

# %% [markdown]
# # **Part 5: Plotting precipitation**
# *(15 pts)*<br>

# %% [markdown]
# <div class="alert alert-info">
#
# **Write a function called `plot_precipitation_bars` that creates a bar graph showing daily precipitation throughout the year.**
#
# **Function parameters:**
# - `days`: array/Series of day-of-year values
# - `precipitation`: array/Series of precipitation depths (in mm)
# - `title`: optional string for plot title (default: "Daily Precipitation")
#
# **Plot requirements:**
# - create a bar graph using `plt.bar()`
# - label both axes clearly
#     - x-axis: "Day of Year"
#     - y-axis: "Precipitation (mm)"
# - include a title
# - add gridlines with 0.3 transparency
# - **Save the figure** as `nashville_precip_2024.png` before showing it
#
# **Test your function:
# After creating your function, call it with the filtered precipitation data from Part 4. Your plot should show the seasonal precipitation patterns in Nashville.**

# %% [markdown]
# **Tips:**
# - consider using a color like `'steelblue'` or `'skyblue'` for the bars
# - the bars might look very thin if you have 366 days - this is normal!
# - remember: `plt.savefig()` must come BEFORE `plt.show()`

# %%
# YOUR CODE HERE

# %% [markdown]
# # **Part 6: Analyzing a Second Location (graduate students or bonus points for undergrads)**
# *(15 pts)*<br>
#
# You've just built a complete weather analysis workflow for Nashville. Now let's see how Boulder, Colorado compares! The Boulder weather data for 2024 is formatted exactly the same as the Nashville data.
#
# Make sure you've downloaded `boulder_weather_2024.csv` from Brightspace and have it uploaded in the correct folder on your ExploreHub.

# %% [markdown]
# ## **Part 6A: Load and Analyze Boulder Data**

# %% [markdown]
# <div class="alert alert-warning">
#
# **Use your existing functions to analyze Boulder weather:**
# - use your `load_weather_data` function to load the Boulder data
# - use your `analyzer_precip` function to get Boulder's precipitation statistics

# %%
# YOUR CODE HERE

# %% [markdown]
# <div class="alert alert-warning">
#
# **Compare the results.**
# 1. Which city had more precipitation in 2024?
# 2. Which city had more sunny days?
# 3. Which city had more snowy days?

# %% [markdown]
# Your answers here.

# %% [markdown]
# ## **Part 6B: Create Comparison Subplots**

# %% [markdown]
# <div class="alert alert-warning">
#
# **Create a 2x2 subplot figure comparing Boulder to Nashville:**
# - top row: temperature plots (Boulder left, Nashville right)
# - bottom plot: precipitation bar plots (Boulder left, Nashville right)
# Both plots should use the same layout and styling for each city for easy comparison.
# Requirements:
# - use `plt.subplots(2,2, figsize=((14, 10))`
# - each temperature plot should show both Tmin and Tmax
# - use consistent colors across both cities (e.g., blue for Tmin, red for Tmax)
# - label all axes clearly
# - add a title to each subplot indicating what is shown
# - add an overall figure title: "Boulder vs Nashville Weather - 2024"
#     - You haven't learned this. I'd like you to practice searching online for help with this one. If you're really stumped, come see me.
# - use `plt.tight_layout()` to prevent overlapping lables
# - save the figure as `boulder_nashville_comparison.png`

# %%
# YOUR CODE HERE

# %% [markdown]
# <div class="alert alert-warning">
#
# **Discussion**: Based on your plots, write 2-3 sentences describing the main differences between Boulder and Nashville weather in 2024

# %% [markdown]
# Your discussion here.

# %% [markdown]
# # **Part 7: Advanced Comparison (bonus points for ALL)**

# %% [markdown]
# <div class="alert alert-warning">
#
# **Create stacked subplots that make it easier to compare temperature and precipitation patterns between two cities.** There are 3 different options below.
# - If you do just one, you will get 3 points for correct plot and 2 points for a thoughtful analysis in your reflection. *That's a total of <u>5</u> bonus points.*
# - If you do just two, you will get 4 points for each correct plot and 2 points for a thoughtful analysis in your reflection. *That's a total of <u>10</u> bonus points.*
# - If you do all three, you will get 4 points for each correct plot and 3 points for a thoughtful analysis in your flection. *That's a total of <u>15</u> bonus points.*
#
#
# **Option A: vertically stacked temperature comparison**
# Create a figure with 4 vertically stacked subplots (4 rows, 1 column):
# 1. Boulder Tmax
# 2. Boulder Tmin
# 3. Nashville Tmax
# 4. Nashville Tmin<br>
# All four should share the same x-axis so the patterns line up perfectly.<br>
#
# **Requirements**:
# - use `sharex=True` in plt.subplots()
# - use the same y-axis range for all plots to enable fair comparison
# - use different colors to distinguish the cities
# - only but x-axis label on the bottom plot
# - add a clear title to each subplot
# - add an overall figure title
#
# **Option B: Side-by-Side with Overlays**
# Create a 1 row, 2 column figure:
# - left plot: Boulder and Nashville temperatures overlaid (all 4 lines on one plot)
# - right plot: Boulder and Nashville precipitation overlaid (both as bars, different colors)<br>
#
# **Requirements**:
#   - use a legend to identify each line/bar
#   - use transparency (`alpha`) to see overlappig data
#   - label axes clearly
#   - make sure the legend is readable
#
# **Option C: Statistical Summary Plot**
# Create a visualization comparing key statistics between the two cities.<br>
# Create a grouped bar chart showing:
# - mean Tmin
# - mean Tmax
# - total precipitation
# - number of sunny days<br>
# (You may need to scale some values to make them visible on the same chart)

# %%
# YOUR CODE HERE

# %% [markdown]
# <div class="alert alert-warning">
#
# **Reflection**: required for bonus points
# Write a paragraph (4-6 sentences, formatted using Markdown/LaTeX syntax) comparing Boulder and Nashville weather based on your analysis. Include:
# 1. Which city has more extreme temperatures?
# 2. Which city receives more precipitation?
# 3. Which city has more variable weather?
# 4. What might explain the differences you observed? (consider geography, elevation, climate zones, etc.)

# %% [markdown]
# Your reflection here.
