# %% [markdown]
# # Assignment 2: Streampower & Erosion in Permafrost Rivers
#
# (YOUR NAME HERE)
#
# (TODAY'S DATE HERE)

# %% [markdown]
# *In solving each of the problems below, please include text comments and description for your future self, so that when you look back you'll have notes on how you solved these problems!*

# %% [markdown]
# ##  <span style="color: purple;"> Motivating Geoscience Problem <span>
#
# There is an ongoing debate about how river bank erosion may be affected in rivers in permafrost landscapes. *Permafrost* is defined as soil that remains frozen through two consequetive summers, except for its very top layer that seasonally thaws (the active layer). This means that in permafrost landscapes, at some depth all the sediment or substrate is frozen, for example in Northern Alaska this can be as little as 40 cm. <br>
#
# #### How does a river carve into frozen banks in permafrost landscapes? Do banks even get eroded?
# It turns out the river partly melts the bank material, while in full summer it may obey more normal sediment transport conditions at least for that top layer.
#
# Satellite data analysis allows mapping of river banks over time, and such analysis appears to show slower rates of bank erosion in Arctic permafrost terrain as compared to other rivers in warmer regions worldwide (Rowland et al., 2023). This would imply that with warming climate, now-still permafrost rivers would perhaps start experiencing more bank erosion? Since the Arctic has been warming rapidly, one could expect to see this effect already in satellite data? However, there is another study that shows very small but slower rates of erosion under climate warming and that study hypothesizes that the growth of more vegetation may slow the rivers with warming climate (Ielpi et al., 2023).
#
# #### A Systems Approach to Understanding Permafrost River Dynamics
#
# To answer these complex questions, we need to analyze **entire river systems** rather than individual sites. Rivers behave as connected river networks where upstream proccess affect downstream conditions and seasonal patterns vary dramatically across different landscape settings. Additionally, **climate change impacts will not be uniform**--mountain headwaters may respond differently than coastal delta segments.
#
# In this assignment, you will conduct a **comprehensive analysis of the Canning River system** in northern Alaska. The river basin is in the continuous permafrost zone, meaning that the entire drainge basin is underlain by permafrost. Our study sites spn from upstream mountain locations in the Brooks Range (Upper Canning and Marsh Fork) to downstram sites in the coastal plain (Staines) and delta (Staines and Cannings Distributaries), draining to the Beaufort Sea.
#
#
# ![CanningRiverMap.png](attachment:CanningRiverMap.png)
#
# Map of the Canning river in the National Arctic Wildlife Refuge, showing the 2 study sites in the upper river basin, and the 3 lowland river sites. The color indicates how much area contributes to the river (with yellow being small contributing upstream area and blue being large areas). *Map courtesy of J. Arcuri.*
#
#
# #### We will address three key research questions:
# 1. How do **streampower and erosion patterns vary** across different segments of a permafrost river system?
# 2. How do **seasonal discharge patterns** affect streampower throughout the river netowrk, and when are different segments most vulnerable to erosion?
# 3. How might **climate change** altar bank erosion patterns across the entire river system over the next century?
#
# By analyzing multiple sites, seasonal patterns, and future climate scenarios, we can build a comprehensive understanding of how permafrost rivers function as integrated systems and how they might respond to continued Arctic warming.

# %% [markdown]
# # 1. $\LaTeX$
#
# Let's place the question of the permafrost bank erosion into the concepts of discharge and streampower.
#
# ### Please use Latex math notation to explain the following concepts and definitions, with their scientific units:
#
# 1. Define **river channel slope** in words and write out the equation for it. Variables used within your equation should either be defined in the explanation above or in a bulleted list below with accompanying units included wherever you decide. <br>
# 2. Define **river discharge** in words and write out the equation for it. Variables used within your equation should either be defined in the explanation above or in a bulleted list below with accompanying units included wherever you decide.<br>
# 3. Define **streampower** in words and write out the equation for it. Variables used within your equation should either be defined in the explanation above or in a bulleted list below with accompanying units included wherever you decide. <br>

# %% [markdown]
# # 2. Creating Data Structures
#
# Suppose we have several river segments of interest (the locations are marked on the map), the elevation at the stretch beginning and at the stretch's end for each of them is listed, so is the field measurement of instantaneous river discharge (taken in July 2023).
# | River Stretch Name| River Stretch <br>Length (m) | Elevation at <br>beginning <br>of stretch (m)| elevation at <br>end <br>of stretch (m) | measured <br>discharge (m<sup>3</sup>/s) |
# |-----|:-------:|:----:|:--------:|:-----:|
# |Marsh Fork            | 2450  |848 |808  |25.0  |
# |Upper Canning         | 2350  |565 |530  |18.8  |
# |Staines               | 2600  |112 |104  |127.3 |
# |Canning Distributary | 1200  |25  |22   |20.1  |
# |Staines Distributary  | 900   |39  |36.7 |115.5 |

# %% [markdown]
# #### a. Create 5 python data structures for this table using lists, where each list represents a single variable (i.e., length, elevation at beginning, elevation at end, discharge)

# %% [markdown]
# #### b. Demonstrate you can print out the values of elevation for the Canning Distributary from your list(s) using indexing.

# %% [markdown]
# #### c. Now create a single python data structure that containes this entire table as a dictionary. Note, you might have to use nested dictionaries...

# %% [markdown]
# #### d. Demonstrate you can print all values for the Staines Distributary from your dictionary using key-value notation.

# %% [markdown]
# ### e. Demonstrate you can print the discharge for the Marsh Fork segment.

# %% [markdown]
# # 3. Slope & Streampower Calculation functions

# %% [markdown]
# ### a. Write a function called `slope_calculator` that returns river channel slope as a global variable, given variables from the Table in Part 2.

# %% [markdown]
# ### b. Write another function called `streampower_calculator` that returns streampower as a global variable, given variables from the Table in Part 2.

# %% [markdown]
# ### c. Using a `for` loop, write a program that calls the functions and calculates respective slopes and streampowers for each river segment in the table in 2. Add the newly calculated variables the dictionary from 2 and print out the slope and stream power for each river stretch (please also print the river stretch names so it's easy to read)
# Suggestion: If you're struggling to start writing your for loop, pick one stretch and write code that would do the above for just that one river stretch. This should help you visualize what you need the for loop to accomplish.

# %% [markdown]
# ## 4. Seasonal Impacts on Discharge and Streampower
#
# In the Table in Part 2, we listed  instantaneous discharge measurements at those locations. Those discharges were measured when we were in the field in July 2023. <br>
# **But, what if they aren't representative?**
#
# From 2008 to 2010, the USGS had a gaging station within our Staines stretch that recorded daily discharges. If you wanted to, you could download this data form the USGS Water for the Nation site here: https://waterdata.usgs.gov/nwis/inventory/?site_no=15955000
#
# ![image.png](attachment:77352ec7-905f-4cde-a495-f32752a791e3.png)
#
# Let's use data from 2009 to explore how seasonality effects streampower. We will use **monthly mean discharge** in m<sup>3</sup> for all of our calculations. Note that in the graph above, discharge is recorded in daily measurements in ft<sup>3</sup>/s. This is typical for USGS data, but the standard for general science is to use the metric system and taking a monthly average makes it easier for now. I've gone ahead and converted those data for your convenience.
#
# | Month from 2009 | *mean* discharge <br>(m<sup>3</sup>/sec)| *max* discharge <br> (m<sup>3</sup>/s) |
# |-----:|:-------:|:------:|
# | January | 0.7 |1.1
# | February | 0.2 |0.3
# | March | 0.0 |0.1
# | April | 0.4 |8.5
# | May | 86.4 |33.98
# | June | 318.9 |818.4
# | July | 125.9 |317.2
# | August | 71.0 |142.7
# | September | 44.5 |101.4
# | October | 9.1 |13.9
# | November | 3.3 |4.0
# | December | 2.3 |2.8
#
# Here is that data in a nested list:

# %%
river_data = [
    ["January", 0.7, 1.1],
    ["February", 0.7, 1.1],
    ["March", 0.7, 1.1],
    ["April", 0.7, 1.1],
    ["May", 0.7, 1.1],
    ["June", 0.7, 1.1],
    ["July", 0.7, 1.1],
    ["August", 0.7, 1.1],
    ["September", 0.7, 1.1],
    ["October", 0.7, 1.1],
    ["November", 0.7, 1.1],
    ["December", 0.7, 1.1]
]

# %% [markdown]
# ### a. Which month has the highest mean river discharge? Demonstrate you know how to grab the index of the month with the highest mean river discharge.

# %% [markdown]
# ### b. Which month has the highest max river discharge? Demonstrate you know how to grab the index of the month with the highest max river discharge.

# %% [markdown]
# ### c. In which months do you think the river is covered in ice? Print out the mean and max discharges of those months. Include descriptive text.

# %% [markdown]
# #### After doing some digging, we discovered additional monthly discharge data for other river segments for the same time period. This allows us to compare seasonal patterns across the entire Canning River system.
#
# Here is the montly discharge data in a dictionary:

# %%
# Seasonal discharge data for multiple river segments (mean monthly discharge in m3/s)
seasonal_discharge_data = {
    'Marsh Fork': [0.1, 0.05, 0.0, 0.1, 22.5, 18.2, 25.0, 15.8, 8.9, 2.1, 0.5, 0.2],
    'Upper Canning': [0.08, 0.03, 0.0, 0.08, 28.4, 22.1, 18.8, 12.3, 6.7, 1.6, 0.4, 0.15], 
    'Staines': [0.7, 0.2, 0.0, 0.4, 86.4, 318.9, 125.6, 71.0, 44.5, 9.1, 3.3, 2.3],
    'Canning Distributary': [0.12, 0.03, 0.0, 0.06, 13.8, 51.1, 20.1, 11.4, 7.1, 1.5, 0.5, 0.37],
    'Staines Distributary': [0.64, 0.18, 0.0, 0.36, 78.6, 290.2, 115.5, 64.6, 40.5, 8.3, 3.0, 2.1]
}

months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# %% [markdown]
# ### d. Which river segment has the highest discharge in June? Write code that extracts all June discharge values and finds which segment has the maximum.

# %% [markdown]
# ### e. Write a nested `for` loop program that analyzes seasonal streampower patterns across all river segments.
# Your program should:
# - have an outer loop that iterates through each river segment
# - have an innter loop that iterates through all 12 months of discharge data
# - use conditional statements:
#     - skip ice months (keeping in mind your answer to c) using continue
#     - if streampower exceeds 50,000 W/m, print a flood warning and use break to stop processing that segment
# - for each ice-free month, calculate and store stream power using your functions and the river slope data from earlier in the assignment

# %% [markdown]
# ### f. After your nested loop, analyze your results and answer these questions:
# 1. Which river segment has the highest average streampower during ice-free months?
# 2. Which month (June through October) shows the highest total streampower when you sum all the segments together?

# %% [markdown]
# ## Data Quality Check: Identifying Anomlaous Discharge Measurements
# Field measurements can sometimes contain errors due to equipment malfunction, ice dams, or recording mistakes. <br>
#
# We found some data for dishcarges from other permafrost rivers and a collaborator of ours let us know some realistic discharges for permafrost rivers.

# %%
permafrost_data = {
    'Test Site A': [0.2, 0.1, -0.5, 0.3, 45.2, 125.8, 89.4, 52.1, 28.7, 5.2, 1.8, 0.4],
    'Test Site B': [0.4, 0.2, 0.0, 0.1, 38.9, 685.3, 112.4, 67.2, 35.1, 7.8, 2.1, 0.6],
    'Test Site C': [0.3, 0.1, 0.0, 0.2, 42.1, 118.7, 78.5, 0.0, 31.4, 6.5, 2.3, 0.5]
}

min_realistic_discharge = 0.0   # Can be zero in winter
max_realistic_discharge = 500.0 # Extreme flood conditions
suspicious_jump_threshold = 50.0 # Flag if month-to-month change exceeds this

# %% [markdown]
# ### g. Write a program using nested `for` loops with `break` and `continue` to check for potentially problematic data.
# Your program should:
# - has an outer loop that checks each site in the dataset
# - has an inner loop that checks each monthly value for that site
# - uses `continue` to skip months that are fine and keep checking
# - uses `break` to stop checking a site one you find the first major problem
# - flags negative values, unrealistically high values, or suspicious month-to-month jumps
# - prints which sites have data qyality issues and what type of problem was found

# %% [markdown]
# # 5. Comparing Current vs. Future Bank Erosion Across the Canning River System
#
# Now that you've analyzed seasonal streampower patterns across all river segments, let's use that data to predict how climate change might affect bank erosion throughou the entire Canning system.
#
# The plot below shows data from Rowland et al. (2023) comparing bank erosion rates between normal rivers and permafrost rivers.
#
# We here look at a data plot from the satelite data analysis study on bank erosion in permafrost rivers in contrast to rivers in lower latitudes (temperate and tropical regions) (Rowland et al., 2023). You can find this paper referenced down below.
#
#
# ![Erosion_streampower_Rowland2023.png](attachment:Erosion_streampower_Rowland2023.png)
#
# >Non-permafrost terrain (circles), and in permafrost terrain (squares). The colors indicate climate zones.
#
# The study found two different relationships:
#
# - for **normal (non-permafrost) rivers**:<br>
# $E  =  0.008  \Omega ^{0.77} $
#
# - for **permafrost rivers**:<br>
# $E  =  0.19  \Omega ^{0.23} $
#
# where:
# - $ \Omega$ is in $W/m^{}$ <br>
# - $ E $ in $ m/year $
#
# You can see how these permafrost rivers (squares) deviate from the larger dataset (circles) and have lower values of erosion for the same streampowers, especially in stretches with large streampower.

# %% [markdown]
# ## The Climate Change Scenario
# By 2109, Arctic warming may cause widespread permafrost thaw. Assume that:
# - discharge patterns remain the same (use your seasonal data from Part 4)
# - river channel geometries stay the same (same slopes)
# - thawed river banks will behave more like normal rivers (i.e., use the normal river equation instead of the permafrost equation)

# %% [markdown]
# ### a. Write functions for erosion for both types of rivers: `permafrost_erosion()` and `normal_erosion()`.

# %% [markdown]
# ### b. Calculate current (2009) vs. future (2109) erosion for ice-free months.
# Using your seasonal discarge data and streampower calculations from Part 4:
# - create numpy arrays of ice-free month discharges (June-October) for each river segment
# - calculate streampower arrays for each segment during ice-free months
# - calculate 2009 erosion using your permafrost function for each segment
# - calculate 2109 erosion using your normal river function for each segment
# - find the difference between future and current erosion for each segment

# %% [markdown]
# ### c. Analysis and Interpretation
# Calculate and report:
# 1. Which river segment shows the biggest increase in erosion with warming?
# 2. Which month (June-October) shows the most dramatic erosion changes across all segments?
# 3. Sum the erosion rate across all segments. How much more total bank erosion would occur system-wide?

# %% [markdown]
# ### d. Compare your results to the existing research
#
# 1. Identify where the Canning system fits in the global context.
#     - from all your calculations in parts (b) and (c), identify the **lowest streampower value** and **highest streampower value** you calculated across all river segments during ice-free months.
#     - report these streampower values along with their corresponding **current erosion rates**.
#     - Looking at the plot from Rowland et al.(2023) above, do your Canning River streampower and erosion values fall within the range shown for permafrost rivers (blue squares)? Are they on the low end, high end, or middle of the permafrost river data?
# 2. Based on your calculations, how much change in bank erosion could we expect in this river system with warming over the next 100 years? Is this significant environmental change?

# %% [markdown]
# ## References
#
# Rowland, J. C., Schwenk, J. P., Shelef,E., Muss, J., Ahrens, D., Stauffer, S.,
# et al. (2023). Scale-dependent influence of permafrost on riverbank erosion rates.
# Journal of Geophysical Research: Earth Surface, 128, e2023JF007101. https://doi.org/10.1029/2023JF007101
#
# Ielpi, A., Lapôtre, M.G.A., Finotello, A. et al. Large sinuous rivers are slowing down in a warming Arctic. Nat. Clim. Chang. 13, 375–381 (2023). https://doi.org/10.1038/s41558-023-01620-9

# %% [markdown]
# # <span style="color: blue;"> For Graduate Students Only (or for Extra Credit for Undergrads) <span>

# %% [markdown]
# # 6. Expanded Climate Change Erosion Modeling
# Climate warming in the Arctic is causing both permafrost thaw AND changes in precipitation patterns. Model how bank erosion at ALL river segments might change over the next 50 years under different warming scenarios.<br>
#
# Here is a dictionary with the different warming scenarios, which store (in $^\circ$C per decade):

# %%
# Climate change scenarios: annual temperature increase (°C per decade)
warming_scenarios = {
    'Conservative': 0.3,    # Slow warming
    'Moderate': 0.5,        # Expected warming  
    'Aggressive': 0.8       # Rapid warming
}

# Permafrost thaw happens when cumulative warming exceeds 2°C
permafrost_thaw_threshold = 2.0

# Precipitation changes with warming (% increase per °C of warming)
precip_increase_per_degree = 8.0  # More rain/snow with warming

# %% [markdown]
# We assert that permafrost thaw happens when cumlative warming exceeds 2 $^\circ$C, so:

# %%
permafrost_thaw_threshold = 2.0

# %% [markdown]
# We assert that precipitation changes with warming (% increase per $^\circ$C of warming), so:

# %%
precip_increase_per_degree = 8.0

# %% [markdown]
# #### a. Write a program that models warming impacts over the next 5 decades using nested and count-controlled `for` loops
# For this exercise, please
# - use an outermost, a middle, and an inner loop
# - makes calculations for decades (not years)
# - use conditional statements to `continue` and `break` where appropriate and switch erosion equations when necessary

# %% [markdown]
# #### b. For each decade, do the following calculations:
# - cumulative temperature increase
# - new discharge (increases with more precip)
# - appropriate erosion rate (permafrost vs normal river equations)
# - bank erosion for that decade

# %% [markdown]
# #### c. After all nested loops, analyze your results by answering these questions:
# 1. Which scenario causes the most total erosion by 2050? by 2070?
# 2. Which river segment is mos vulnerable to climate change?
# 3. In which decade do most segments transition from permafrost to normal rivers?

# %% [markdown]
# ## 7. Anaconda Installation
#
# - Install Anaconda on your own machine following instructions posted separately with this assignment.
# - upload a screenshot of your Spyder window terminal showing you are in your new python interpreter.
#     - you can do this by making a new Markdown cell and use "Insert Image" under the "Edit" tab in the notebook
