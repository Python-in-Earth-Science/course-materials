# %% [markdown]
# # Lecture 02 — Variables & Operators
# ### EES 3350/5350 · Python in Earth Science · Monday, August 31, 2026
#
# **Learning objectives for today**
# - Create and use variables to store data
# - Identify Python's basic data types: `int`, `float`, `str`, `bool`
# - Change a variable's data type
# - Use variables in calculations
# - Recognize and interpret a basic Python error message

# %% [markdown]
# ---
# ## 🌡️ Warm-Up (TopHat — 2 minutes)
#
# Today's warm-up is a quick check on Friday's `os` and paths material — answer within the first few minutes for credit.

# %% [markdown]
# ---
# <div class="alert alert-danger">
#
# ### Have you made a copy of this file??
# Make sure you've followed our typical workflow!
#
#         Open from `course-materials/` → rename → copy to your personal folder → work there.

# %% [markdown]
# ---
# ## Part 1 — Variables
#
# ### What is a variable?
#
# A **variable** is a name that points to a value stored in the computer's memory. Think of it like a labeled jar — you can put something in it, look inside it, or swap out its contents later.
#
# ```python
# distance_km = 347
# ```
#
# Here, `distance_km` is the name, and `347` is the value it points to.

# %% [markdown]
# Run the following cell:

# %%
# Run this cell
distance_km = 347
print(distance_km)

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 1: </b>
#
# What was printed above?

# %% [markdown]
# > Type your answer in this Markdown cell.

# %% [markdown]
# ### Naming variables
#
# Python has a few hard rules, and we'll also follow a course convention:
#
# | Rule | Example |
# |---|---|
# | Must start with a letter or underscore (not a number) | `age_ma` ✅, `2age` ❌ |
# | Case-sensitive | `Distance` and `distance` are different variables |
# | Can't use Python reserved words (`print`, `for`, `import`, etc.) | `print = 5` ❌ |
# | Use `snake_case` (lowercase, words separated by underscores) — course convention | `distance_km` ✅, not `DistanceKM` |
#
# Good variable names describe *what* they hold — `age_ma` is much clearer than `x`.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Question 2:</b>
#
# Which of these are valid Python variable names? Which follow our course naming convention?
#
# <code>1age</code>, <code>rock_type</code>, <code>Mineral-Name</code>, <code>mass_kg</code>, <code>class</code>
# </div>

# %% [markdown]
# > Type your answer in this Markdown cell.

# %% [markdown]
# ---
# ## Part 2 — Operators
# An **operator** tells Python to perform a given operation on two **operands**
# ```
# operand  operator  operand
#    3         +        4
# ```
# In python..
# | Symbol      | Operation |
# |-------------|-----------|
# | + | addition |
# | - | subtraction |
# | * | multiplication |
# | / | division |
# | ** | raise to power |
# | % | modulo (remainder after division) |

# %% [markdown]
# You can use a programming language as a calculator. If you want to do that you will be using *arithmetic operators*.
#
# - *Operators* define the type of calculation that is executed.
# For example, the `+` operator
#
# - Any operator works on *operands*.
# To extend the example below: the `+` operator adds the operands a and b together

# %% [markdown]
# #### Let's see how this could work with some random variables.

# %%
a = 10
b = 45
c = 3
d = 5
e = 2
f = 18
g = 7

# %% [markdown]
# **Let's first add `a` and `b`.**

# %%
z = a + b
print("a + b =", z)

# %% [markdown]
# We could also just write:

# %%
print("a + b =", a+b)

# %% [markdown]
# **Now let's multiple `c` and `d`.**

# %%
y = c * d
print("c * d =", y)

# %% [markdown]
# or

# %%
print("c * d =", c*d)

# %% [markdown]
# **The modulo operator is pretty cool, it gives you the remainder after division. Let's see what the remainder is when we divide `f` by `g`.**

# %%
x = f%g
print("f % g =", x)

# %% [markdown]
# or

# %%
print("f % g =", f%g)

# %% [markdown]
# **And finally, let's raise `d` to the `e`th power.**

# %%
v = d**e
print("d^e = ", v)

# %% [markdown]
# or

# %%
print("d^e = ", d**e)

# %% [markdown]
# <div class="alert alert-success">
#
# **A note about arithmetic operator precedence:**
#
# Operator precedence defines the order in which operations are performed.
# <p><u>Here's what you need to know:</u>
#
# 1. Parentheses have the highest precedence, meaning that expressions inside parentheses are evaluated first.
#
# 2. Exponation `**` has precedence over multiplication `*`
#
# 3. Multiplication `*` has higher precedence than addition `+` and substraction `-`, and therefore multiplications are evaluated before additions.
#
# 4. Multiplication `*` is at the same *precendence level* as division `/`, and the statement is executed left to right. This is the same for addition and substraction.

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 1
#
# Let's determine the cross sectional area of the Earth in meters, given that we only know the circumference of the Earth and equations for the circumference and the area of a sphere.
# $$ \text{circumference of the Earth} =  2 \pi r = 40,075 \space \text{km}$$
# $$ \text{cross-sectional area of a sphere} = \pi r^2 $$
#
# **Using the equations above, <u>as a class</u>, write an equation to determine the cross-sectional area of the Earth in with respect to the circumference of the Earth in the following Markdown cell.**
#
# **<u>By yourself</u>, in the code cell that follows, using variables and python math operators.**
# </div>

# %% [markdown]
# The following is an equation that solves for cross-sectional area of a sphere using the circumference of the sphere:
# $$ equation goes here$$

# %%
# create a circumference variable
circumference = _________
# use the following for pi
pi = 3.1415
# translate your equation here
crosssection_area = _______________________
print("The surface area of the Earth is", crosssection_area, "km^2")

# %% [markdown]
# ### The assignment operator `=`
#
# In Python, `=` is the **assignment operator** — it is *not* a statement of equality.
#
# | What `=` does | Notes |
# |---|---|
# | Assigns the value on the right to the name on the left | The variable "gets" the value |
# | Defines the variable if it doesn't already exist | No need to declare a type first |
# | Overwrites the old value if the variable already exists | The previous value is gone |
#
# <div class="alert alert-success">
#
# **Tip:** Read `x = 5` as "x gets 5," not "x equals 5."

# %% [markdown]
# ### Comparison operators
# Comparison operators compare two values and returns either `True` or `False`
# | comparison operator | What it does | Example |
# |---|---|---|
# | `==` | is the value on the left equal to the value on the right | `age = 33` ; `age == 61` will return `False` |
# | `!=` | is the value on the left UNEqual to the value on the right | `age == 61` will return `True` |
# | `>` | is the value on the left greater than the value on the right | `age > 61` will return `False` |
# | `<` | is the value on the left less than the value on the right | `age < 61` will return `True` |
# | `>=` | is the value on the left greater than or equal to the value on the right | `age >= 61` will return `False` |
# | `>=` | is the value on the left less than or equal to the value on the right | `age <= 61` will return `True` |
#
# Comparison operators will return a data type called a `boolean` variable or a `bool`
# ### `bool`s
# A boolean variable can have only one of two possible values: `True` or `False`

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Question 3:</b>
#
# What do you think each line of following code cell will return? Write your predictions in the Markdown cell below and then run the code cell to see if you're right.

# %% [markdown]
# > Type your answer in this Markdown cell.

# %%
print(5!=5)
print(5!=10)
print(6>3)
print(6<3)
print(6<=3)
print(6>=6)

# %% [markdown]
# ### Basic data types
#
# You just learned about the data type `bool`. It turns out every variable has a **type**. A type will describe what kind of value it holds. The ones we'll use constantly:
#
# | Type | What it holds | Example |
# |---|---|---|
# | `int` | whole numbers | `age = 61` |
# | `float` | decimal numbers | `age = 61.3` |
# | `str` | text, wrapped in quotes | `name = "Suiko"` |
# | `bool` | boolean; True or False | `age = 33` ; `age == 61` will return `False` |
#
# Use the built-in `type()` function to check a variable's type.
#
# Let's explore some variable types.

# %%
# variable examples
seamount_name = "Suiko"
age_ma = 61.3
sample_count = 12
age_check = age_ma >= 61

print(type(seamount_name))
print(type(age_ma))
print(type(sample_count))
print(type(age_check))

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** You can store `bools` as variables, like we did above with `age_check`. This is very handy!

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 2
#
# Print the data type of `distance_km` from earlier.
# </div>

# %%
print(______________)

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 2 cont.
#
# Does this data type store decimals?

# %% [markdown]
# > Type your answer in this Markdown cell.

# %% [markdown]
# ### Using variables in calculations
#
# Once a value is stored in a variable, you can use it in arithmetic just like a number — and store the result in a *new* variable.
#
# Suppose a lava flow traveled 12 km over 3 hours. What's its average speed?

# %%
distance_km = 12
time_hr = 3

speed_km_per_hr = distance_km / time_hr
print(speed_km_per_hr)

# %% [markdown]
# ### Reassigning a variable
#
# If we assign a new value to `distance_km`, the old value (12) is gone — replaced by whatever we assign next.

# %%
distance_km = 12
print("First value:", distance_km)

distance_km = 20
print("After reassignment:", distance_km)

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 3
#
# - Create variables for a *different* lava flow: it traveled 18 km over 4.5 hours
# - Calculate its average speed and store it in a new variable
# - Print the result with a `print()` statement
# </div>

# %%
# replace the underscores with the appropriate thing
# distance variable
distance_km = ______________

# time variable
______________  = 4.5

# average speed calculation
avg_speed = ______________
print("The average speed of this lava flow is", ______________, "km per hour.")

# %% [markdown]
# ### Converting from one type to another
# Sometimes your variables end up as the wrong data type. There are native python functions that will convert variables from one type to another. For example:
# - `int()` converts a value to an integer
# - `float()` converts a value to a float
# - `str()` converts a value to a string

# %%
# some examples
print(int(3.1415))
print(float(5))
print(str(6.0-3e22))

# %% [markdown]
# Let's practice on some variables. Run the following cell to set up some variables. Then complete the Exercise

# %%
planet = 'Mercury'
planet_number = 1
solar_irradiance = 9083.0

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 4
#
# - Print out the `type()` of each of the three variuables above. Verify that you get the following printed out:
# ```python
#     <class 'str'>
#     <class 'int'>
#     <class 'float'>
# ```

# %%
# fill in the blanks to determine what type each variable is
# name of planet
print(______________)
# planet number
print(______________)
# planet irradiance
print(______________)

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 4 cont.
#
# Re-cast the variable types as follows and print the output.
# - planet number to a float
# - solar irradiance to an integer
# - solar irradiance to a string
# - solar irradiance back to a float
# - planet name to a float or integer
#
# Did all of these work?

# %%
# fill in the blanks to change the variable types
# planet number to a float
planet_number_flt = ______________
print("Planet number as a float:", planet_number_flt)
# solar irradiance to an integer
solar_irradiance_int = ______________
print("Solar irradiance as an integer:", solar_irradiance_int)
# solar irradiance to a string
solar_irradiance_str = ______________
print("Solar irradiance as a string:",solar_irradiance_str)
# solar irradiance from string back to an float
solar_irradiance_flt = ______________
print("Solar irradiance as a float:",solar_irradiance_flt)
# planet name to a float
planet_name_flt = ______________
print("Planet name as a float:", planet_name_flt)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Question 3:</b>
#
# Why do you think we **couldn't** convert the planet name to a float?

# %% [markdown]
# > Type your answer in this Markdown cell.

# %% [markdown]
# ---
# ## Reading An Error Message
#
# Let's talk about that error message. We got a `ValueError` message when we tried to convert a string that wasn't made of numbers to a float. Let's recreate that by running the cell below again.

# %%
planet_name_flt = float(planet)
print("Planet name as a float:", planet_name_flt)

# %% [markdown]
# #### **What happened?**
#
# Python raised a `ValueError`. This error happesn when you try to convert something into a number, but the thing you're converting isn't actually a number. In this particular case, python has no idea how to turn the word "Mercury" inot a number, so it raises a `ValueError1 to tell you that it can't complete the conversion.
#
# A few tips for reading error messages:
# - Read the **last line first** — it usually names the type of error and gives the key detail
# - The arrow (`---->`) points to the line where Python got stuck
#
# #### Types of common errors:
# | Error Type | What It Means | Example |
# |---|---|---|
# | `SyntaxError` | Code isn't valid Python "grammar" — happens before code runs | `if x = 5:` (should be `==`) |
# | `NameError` | Using a variable/function name that doesn't exist | `print(totl)` when `totl` was never defined |
# | `TypeError` | Wrong *type* of value for the operation — no value of that type would work | `"5" + 5` |
# | `ValueError` | Right type, but an invalid *value* for that type | `int("hello")` |
# | `IndexError` | Accessing a list/string/tuple position that doesn't exist | `my_list[10]` on a 3-item list |
# | `KeyError` | Accessing a dictionary key that doesn't exist | `my_dict["b"]` when `"b"` isn't a key |
# | `AttributeError` | Using a method/property that doesn't exist on that object | `"hello".append("!")` |
# | `FileNotFoundError` | Trying to open a file that doesn't exist at that path | `open("myfile.txt")` |
# | `ZeroDivisionError` | Dividing by zero | `10 / 0` |
# | `ImportError` / `ModuleNotFoundError` | Trying to import a package/module Python can't find | `import pandsa` (misspelled) |

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 5
#
# A geologist weighs a quartz sample at 79.5 g and finds it displaces 30 cm³ of water. Run the following cells.
#
# </div>

# %%
mass_gram = 79.5
volume_cm3 = 30

density = mass_gam / volume_cm3
print(density)

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 5 cont.
# What type of error occured here and why? How would you fix it?

# %% [markdown]
# > Type your answer in this Markdown cell.

# %%
# fix the error here and run the cell
mass_gram = 79.5
volume_cm3 = 30

density = mass_gam / volume_cm3
print(density)

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** Error messages are very Google-able! If you don't understand what the error means, try searching for the type of error on a search engine!

# %% [markdown]
# ---
# ## Bonus Material (if time)

# %% [markdown]
# Two extras — nicer-looking output, and a few more $\LaTeX$ symbols for equations with sums or ranges.

# %% [markdown]
# ### Bonus: Cleaner printing with f-strings
#
# So far we've printed variables like this, separating pieces with commas:
#
# ```python
# print("The density of", mineral_name, "is", density, "g/cm3")
# ```
#
# Python has a cleaner way to build printed text: **f-strings**. Put an `f` right before the quotation marks, and any variable name inside `{ }` gets swapped in automatically.

# %%
mineral_name = "quartz"
density = 2.65

# old style
print("The density of", mineral_name, "is", density, "g/cm3")

# f-string style
print(f"The density of {mineral_name} is {density} g/cm3")

# %% [markdown]
# <div style="background-color:#e8daef; border:1px solid #d2b4de; color:#6c3483; padding:15px; border-radius:4px; margin-bottom:20px;">
# <b><u>Bonus Exercise</u></b><br>
#
# Go back to Exercise 1 (the lava flow speed calculation) and copy it to the cell below. Add a new <code>print()</code> statement below your original one that reports the result using an f-string instead, e.g. something like "The lava flow traveled at ___ km/hr."
# </div>

# %%
# write your answer in this cell code and execute it

# %% [markdown]
# ### Bonus: A few more $\LaTeX$ symbols
#
# | Element | Syntax | Renders as |
# |---|---|---|
# | Summation | `\sum_{i=1}^{n}` | $\sum_{i=1}^{n}$ |
# | Integral | `\int` | $\int$ |
# | Plus/minus | `\pm` | $\pm$ |
# | Degree | `^\circ` | $^\circ$ |
# | Infinity | `\infty` | $\infty$ |
#
# These show up when we start summing measurements across samples, reporting uncertainty (e.g. an age of $61.3 \pm 0.2$ Ma), or working with temperatures in $^\circ C$.

# %% [markdown]
# <div style="background-color:#e8daef; border:1px solid #d2b4de; color:#6c3483; padding:15px; border-radius:4px; margin-bottom:20px;">
# <b><u>Bonus Exercise</u></b><br>
#
# Edit the Markdown cell below and typeset the following in display math:
# - a sample's age with its uncertainty, e.g. $43.4 \pm 0.3$ Ma
# - a temperature in degrees Celsius, e.g. $15^\circ C$
# </div>

# %% [markdown]
# > Type your answer in this Markdown cell.
