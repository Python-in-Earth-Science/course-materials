# %% [markdown]
# # EES 3350/5350— Introduction to Python in Earth Science
# ### Lecture 00 &nbsp;·&nbsp; Wednesday, August 26, 2026
#
# **Learning objectives for today**
# - Log into the CSDMS ExploreHub and understand what it is
# - Know the difference between markdown cells and code cells
# - Write basic Markdown formatting
# - Write simple $\LaTeX$ math equations
# - Run your first code cell
# - Set up TopHat for in-class warm-up problems

# %% [markdown]
# ## Before you go any futher, rename this notebook by adding a `_YourLastNameHere` to your document before you start working. This will make this document "yours" instead of linked to the GitHub Repository version of it. (Don't worry you'll learn more about all that throughout the semester.)

# %% [markdown]
# ## How you got here
#
# You opened this notebook by clicking a button on the [course website](https://python-in-earth-science.github.io). That button used a tool called **nbgitpuller** to automatically copy this file from our course GitHub repository directly into your ExploreHub account.
#
# This is how you'll get all lecture notebooks for the first few weeks: **click the button, notebook appears, start working**. No downloading, no uploading, no installing anything on your own computer.
#
# Later in the semester you'll learn exactly how this works under the hood — it uses the same version control system (Git) that scientists use to collaborate on code and track changes to their work. For now, just enjoy the magic.

# %% [markdown]
# ## The CSDMS ExploreHub
#
# We are running Python in the cloud using [JupyterLab](https://jupyter.org/) hosted on the **CSDMS ExploreHub** — a computing environment maintained by the Community Surface Dynamics Modeling System at CU Boulder. It is free for students in this course and has all the scientific Python packages we need pre-installed.
#
# **Key things to know:**
# - Your files live on the ExploreHub server, not on your personal computer
# - You access it through a web browser — no installation required
# - You can log in from any device with internet access
# - **Save your work regularly** with `Ctrl+S` (or `Cmd+S` on Mac) — the Hub does not autosave by default

# %% [markdown]
# <div class="alert alert-info">
# <b><u>Exercise 1: Get oriented in JupyterLab</u></b><br><br>
#
# Take 2 minutes to explore the JupyterLab interface. Find the following:
#
# 1. The **file browser** on the left sidebar — this shows your files and folders. You should see this notebook (`00_course_intro.ipynb`) listed here.
# 2. The **kernel indicator** in the top right corner of this notebook — it should say `Python 3`. The kernel is the computational engine running your code.
#    Click `Python 3` and change it to `CSDMS`
#    ![image.png](attachment:8e2dc32a-f0f5-4af7-a2d7-82b453646c21.png)
# 4. The **toolbar** at the top of the notebook — find the buttons to run a cell (▶), add a cell (+), and save (💾).
#
# Once you've found all three, continue to the next section.
# </div>

# %% [markdown]
# ## Why Python?
#
# This course teaches Python — one of the most widely used languages in scientific computing. A few reasons we use it:
#
# - **Readable**: Python code is close to plain English, which makes it easier to learn and to share with collaborators
# - **Powerful**: the scientific Python ecosystem (NumPy, pandas, Matplotlib, and more) covers almost everything you'd need for data analysis, visualization, and modeling
# - **Everywhere**: Python is used across Earth science, climate modeling, hydrology, geophysics, remote sensing, and beyond — knowing it opens a lot of doors
# - **Free and open source**: no licenses, no cost, runs on any machine
#
# The goal of this course is not to make you a software engineer — it is to make you a scientist who can write code to answer scientific questions.

# %% [markdown]
# ## Jupyter notebooks
#
# A Jupyter notebook (like this one) is made up of **cells**. There are two types you'll use constantly:
#
# | Cell type | What it contains | How to run it |
# |-----------|-----------------|---------------|
# | **Markdown** | Formatted text, equations, images | `Shift + Enter` |
# | **Code** | Python code | `Shift + Enter` |
#
# **Markdown cells** render formatted text when you run them. You're reading one right now. Double-click any markdown cell to see its raw source.
#
# **Code cells** send your Python code to the kernel, execute it, and display the output directly below the cell.
#
# > **Tip:** You can always tell which type a cell is by looking at the dropdown menu in the toolbar — it will say "Markdown" or "Code".

# %% [markdown]
# <div class="alert alert-info">
# <b><u>Exercise 2: Markdown vs. code</u></b><br><br>
#
# 1. Double-click on this cell to see its raw Markdown source.
# 2. Run it again with `Shift + Enter` to render it back to formatted text.
# 3. Click on the empty code cell directly below this one and run it with `Shift + Enter`. Notice the difference in how the output appears.
# </div>

# %%
# This is a code cell. Run me with Shift+Enter.
print("Hello from a code cell!")

# %% [markdown]
# ## Markdown basics
#
# Markdown is a lightweight formatting language. Here are the most useful things to know:
#
# | What you type | What you get |
# |---|---|
# | `# Heading 1` | # Heading 1 |
# | `## Heading 2` | ## Heading 2 |
# | `### Heading 3` | ### Heading 3 |
# | `**bold**` | **bold** |
# | `*italic*` | *italic* |
# | `- item` | bullet point |
# | `` `code` `` | `inline code` |
#
# A blank line between paragraphs creates a new paragraph. Two spaces at the end of a line creates a line break.

# %% [markdown]
# Here's an example of a well-formatted notebook cell — this is the kind of documentation we'll expect in your work:
#
# ---
#
# ### Calculating the volume of a sediment deposit
#
# The deposit can be approximated as a rectangular prism:
#
# - **Length** = 450 m
# - **Width** = 120 m
# - **Average depth** = 3.5 m
#
# The estimated volume is therefore **189,000 m³**.
#
# ---

# %% [markdown]
# <div class="alert alert-info">
# <b><u>Exercise 3: Your first Markdown cell</u></b><br><br>
#
# 1. Click the **+** button in the toolbar to add a new cell below this one.
# 2. Change it to a Markdown cell using the dropdown in the toolbar.
# 3. In the new cell, write a short introduction to yourself as a scientist: your name, your year, and one Earth science topic you're curious about.
# 4. Include at least one **bold** word, one *italic* word, and use a `### third-level heading`.
# 5. Run the cell with `Shift + Enter` to render it.
# </div>

# %% [markdown]
# ## $\LaTeX$ math in notebooks
#
# In Markdown cells we can write properly typeset math using $\LaTeX$ (pronounced "lay-tek"). You'll use this a lot in this course — any time you want to document what equation your code is computing.
#
# There are two modes:
#
# **Inline math** — wrap with single dollar signs, renders within a sentence:
# `The slope angle $\theta$ is measured in degrees.` → The slope angle $\theta$ is measured in degrees.
#
# **Display math** — wrap with double dollar signs, renders on its own line:
# ```
# $$Q = A \cdot v$$
# ```
# $$Q = A \cdot v$$

# %% [markdown]
# #### Common $\LaTeX$ symbols you'll use in this course
#
# | What you type | What you get | Name |
# |---|:---:|---|
# | `$\pi$` | $\pi$ | pi |
# | `$\theta$` | $\theta$ | theta |
# | `$\alpha$` | $\alpha$ | alpha |
# | `$x^{2}$` | $x^{2}$ | superscript |
# | `$x_{i}$` | $x_{i}$ | subscript |
# | `$\frac{x}{y}$` | $\frac{x}{y}$ | fraction |
# | `$\sqrt{x}$` | $\sqrt{x}$ | square root |
# | `$\approx$` | $\approx$ | approximately equal |
# | `$\Delta$` | $\Delta$ | delta (change in) |
#
# A more complete reference sheet is linked on the course website.

# %% [markdown]
# <div class="alert alert-info">
# <b><u>Exercise 4: Write a $\LaTeX$ equation</u></b><br><br>
#
# In a new Markdown cell below:
#
# 1. Write a sentence that uses at least one **inline** equation. For example, you could describe a relationship like "The discharge $Q$ equals velocity times cross-sectional area."
# 2. On a new line, write the same relationship as a **display** equation.
#
# If you're not sure what equation to use, try the Stefan-Boltzmann law from Earth's energy balance: the power radiated per unit area is $M = \sigma T^4$, where $\sigma$ is the Stefan-Boltzmann constant and $T$ is temperature in Kelvin.
# </div>

# %% [markdown]
# ## Code cells
#
# Code cells contain Python. When you run one, the kernel executes the code and displays any output below the cell.
#
# A few things to know:
# - Lines starting with `#` are **comments** — they are ignored by Python but essential for human readers
# - `print()` outputs text to the screen
# - Variables and results from one cell are available in all cells below it (as long as you've run the cells in order)

# %% [markdown]
# Here's a simple example — a calculation you might actually do in your research:

# %%
# Estimating the volume of a landslide deposit
# Data from field measurements

length = 450      # meters
width = 120       # meters
avg_depth = 3.5   # meters

volume = length * width * avg_depth

print("Estimated deposit volume:", volume, "cubic meters")
print("That's equivalent to", round(volume / 2400, 1), "Olympic swimming pools.")

# %% [markdown]
# <div class="alert alert-info">
# <b><u>Exercise 5: Your first code cell</u></b><br><br>
#
# In a new code cell below:
#
# 1. Create three variables representing measurements of your choice (a distance, a temperature, a time — anything with units).
# 2. Perform a simple calculation using them.
# 3. Use `print()` to display the result with a descriptive label and units.
# 4. Add at least two comments (`#`) explaining what you're computing.
#
# Don't worry about getting the "right" answer — this is about getting comfortable with the syntax.
# </div>

# %%
# Your code here

# %% [markdown]
# ## TopHat: in-class warm-up problems
#
# Starting **Friday**, every lecture will begin with a short **warm-up problem** delivered through TopHat. Here's how it works:
#
# - A question appears on the projector at the start of class
# - You open TopHat on your phone or laptop and answer
# - TopHat timestamps your response — answering in the first few minutes counts
# - Warm-up problems are short: usually one or two code cells worth of thinking
# - They count toward your participation grade (15% of final grade)
#
# **The warm-up grade rewards showing up on time and being ready to work.** There's no penalty for a wrong answer — only for not answering.
#
# ### Setting up TopHat
#
# 1. Go to [tophat.com](https://tophat.com) and create a free student account using your Vanderbilt email
# 2. Use the course join code: **357406**
# 3. Download the TopHat app on your phone (optional but convenient)
#
# Do this before Friday's class.

# %% [markdown]
# <div class="alert alert-success">
# <b>&#9200; TopHat Warm-up</b><br><br>
#
# **Practice warm-up — TopHat activity**
#
# This is a preview of what Friday's warm-up will look like.
#
# Look at the code cell below. **Before running it**, write your prediction in the Markdown cell provided:
# - What will Python print?
# - Will there be an error? Why or why not?
#
# Then run the cell and check your prediction.
# </div>

# %%
x = 10
y = 3
print("Sum:", x + y)
print("Product:", x * y)
print("Is x greater than y?", x > y)

# %% [markdown]
# *Your prediction here — double-click to edit this cell.*
#
# I predicted that the output would be...

# %% [markdown]
# ## Before Friday
#
# 1. **Save this notebook** — `Ctrl+S` (Windows) or `Cmd+S` (Mac)
# 2. **Set up TopHat** using the join code above and confirm you can log in
# 3. **Revisit the $\LaTeX$ reference sheet** on the course website — Friday's notebook uses equations throughout
#
# On Friday we'll pick up with operators, how Python handles numbers, and our first real geoscience calculation: estimating Earth's average surface temperature from first principles.
#
# See you then.
