# %% [markdown]
# ![image.png](attachment:3d755ea1-1a34-452b-ac65-b0a918ed3a77.png)

# %% [markdown]
# **Learning Objectives**
#
#   - some computing basics
#   - logging onto the Explore JupyterHub
#   - Using Jupyter notebooks
#   - Markdown cells vs. Code cells
#   - $LaTeX$ basics
#   <br>

# %% [markdown]
# ## What is a (digital electronic) computer?
#
# Merriam-Webster: "a programmable usually electronic device that can store, retrieve, and process data"
#
# Data are encoded electronically as binary information
#
# A computer's **random access memory** (RAM) encodes information in (nowadays) billions of tiny electronic circuits, each of which can be in either of two states (low vs. high voltage), which are used to represent a 0 or a 1
#
# A **bit** is one binary digit (0 or 1)
#
# A **byte** is 8 bits

# %% [markdown]
# ## What is a computer program?
#
# ### Answer: a series of instructions to be performed by a computer

# %% [markdown]
# A simple example:

# %%
seconds_per_minute = 60
minutes_per_hour = 60
hours_per_day = 24
days_per_year = 365.25
seconds_per_year = days_per_year * hours_per_day * minutes_per_hour * seconds_per_minute
print("There are", seconds_per_year, "seconds in an average year.")
# Out:
# There are 31557600.0 seconds in an average year.

# %% [markdown]
# A more complex example:

# %%
wx = input("What is the weather like today? ")
print("Good luck with that", wx, "weather.")
# Out:
# What is the weather like today?  raining cats and dogs
# Good luck with that raining cats and dogs weather.

# %% [markdown]
# ## What is a programming language?
#
# - Computers are electronic machines that perform operations on binary data
# - Instructions are encoded in binary *machine code*
# - A **programming language** is a special kind of language that can be translated into machine-language instructions
# - Examples of languages: BASIC, APL, Pascal, Fortran, C, C++, Python, R, Java, JavaScript, Julia

# %% [markdown]
# ## Compiled versus interpreted languages
#
# - **Compiled**: an entire program (the *source code*) is translated into a binary *executable* file, which can then be run on a particular computer architecture.
#   - PROS:
#     - Usually faster to run than interpreted programs
#     - Executable code is separate from source code
#   - CONS:
#     - Requires extra steps during development
#     - Source code must be *compiled* for each type of hardware

# %% [markdown]
# ## Compiled versus interpreted languages
#
# - **Interpreted**: when a program is run, individual lines of code are translated into binary and executed one at a time.
#   - PROS:
#     - Programs tend to be faster to write
#     - Source code *is* the program
#     - Portable from one kind of computer to another (as long as an interpreter is installed)
#   - CONS:
#     - Requires an *interpreter* to run
#     - Often slower to execute than compiled code

# %% [markdown]
# ## Why Python?
#
# - **Developed in early 1990s by [Guido van Rossum](http://neopythonic.blogspot.com/2016/04/kings-day-speech.html)**
# - **One of the most popular languages for scientific computing**
# - **Interpreted**
# - **Rich and growing set of scientific libraries**
# - **Can express ideas quickly and efficiently**
#
# *"The first version of Google was written in Python. The reason: Python was the right language to express the original ideas that Larry Page and Sergey Brin had about how to index the web and organize search results."* (Guido van Rossum, 2016)

# %% [markdown]
# # EarthscapeHub : explore
#
# <img align="right" style="margin:0 0 20px 20px" width="35%" height="35%" src="https://csdms.colorado.edu/csdms_wiki/images/OpenEarthscape_logo.png">
#
# In this course, we will be using the *explore* instance of [EarthscapeHub](https://csdms.colorado.edu/wiki/JupyterHub).
# It's designed for running workshops and classes
# with a few to dozens of participants.
# It's free and available for use by all CSDMS members,
# whether you're an undergraduate,
# grad student, postdoc, researcher, or faculty.
#
# Has really great help options! [CSDMS Help Desk](https://csdms.github.io/help-desk).

# %% [markdown]
# ## user interface
#
# The default user interface on this Hub is [JupyterLab](https://jupyter.org/).
# If you haven't used JupyterLab before,
# there's ample [documentation](https://jupyterlab.readthedocs.io/).

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise </b></u> <br>
#
# - Navigate to the CSDMS JupyterHub https://lab.openearthscape.org
# - Login with your email address as it appears on the Vanderbilt registration list (usually givenname.middleinitial.surname@vanderbilt.edu)
# - The first time you log in you will need to create a password; please write it down!

# %% [markdown]
# ![oes_login.png](attachment:oes_login.png)

# %% [markdown]
# ## Getting to know the JupyterLab environment
#
# - File/folder browser
# - Launcher: Notebook, Console, Other

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 0.1</b></u> <br>
#
# - In the file/folder browser, create a new folder and name it `InClass_Notebooks`
# - Navigate into the folder by double-clicking it
# - Click the + button in the upper left to open the Launcher
# - From the launcher, create a new Jupyter Notebook that uses Python 3.
# - Rename it `<lastname>_week01.ipynb`
#   - To rename a file, right-click on it and select `Rename` from the drop-down menu
#   - for example: `morey_week01.ipynb`
# - Navigate back to your home folder.
# - Create a new folder and name it `Lecture_Notebooks`
#
# You should now have 2 new folders in your home directory:
# - InClass_Notebooks
# - Lecture_Notebooks
#
# **Note: we won't use spaces in our file or folder names.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 0.2</b></u> <br>
#
# - Now that you've learned to create a new file, let's figure out how to upload files to the explore Hub.
# - First, go to Brightspace and download the file "01_course_intro.ipynb".
# - Then, press the`upload files` button (the arrow pointing up - should be to the right of the blue plus button in the sidebar). Find the "01_course_intro" file and upload it.
# - Now let's move it into the right folder.
#   - Open a terminal (shell) on hub
#   - Type the following commands, pressing enter after each one
#   - `ls` - this lists all the files and folders in your current directory
#   - `mv 01_course_intro.ipynb Lecture_Notebooks`
#   - `cd Lecture_Notebooks` - this will navigate you into your newly created folder
#   - `ls` - to see the files present. You should see the file within your new "InClassNotebooks" folder
#   - `ls -l` - this lists the long, full names of the files and folders in your current directory
#
# It's good to get in the habit of downloading the lecture notebooks and storing them in this `Lecture_Notebooks` folder. You can also store them locally, but if you store them on your Explore Hub, you can access them on any computer that has internet.

# %% [markdown]
# ### *All of the exercises from now on should be done in your in-class notebooks.*

# %% [markdown]
# ## Basics of Jupyter notebooks
#
# Notebooks run through a web browser using *kernels*, which is a separate computational process that runs in the background. When you type code in a Jupyter notebook cell and hit `Shift+Enter`, here's what happens:
# 1. Your code gets sent from the notebook interface to the kernel
# 2. The kernel executes the code in its own environment
# 3. Any output, errors, or results get sent back to display in your notebook
#
# Different kernels may have different libraries installed. We'll be using the **CSDMS kernel**, which already has everything we need installed.
#
# #### <u>Always check your kernel before you start coding. </u>
# - Look at the top-right corner of your notebook - you'll see something like "Python 3".
# - Click on the kernel name.
# - Select the correct kernel from the dropdown menu (in our case CSDMS)
# - Wait a few seconds for it to switch
#
# #### <u>A notebook contains one or more **cells**</u>
# - To **create a new cell**, click the + button on the toolbar (or use keyboard shortcuts `a` or `b`)
#   - Enter *edit mode* by double-clicking
#   - Enter *view mode* by running the cell (> Run button, or type Shift+Return)
# Two main kinds of cell:
#
# - **Markdown** cells are for formatted text and pictures
# - **Code** cells are for (in this case) Python code
# - The default cell type is a **Code** cell
# - You can change the type of cell with the dropdown menu on the toolbar or click to the left of the cell and use type:
#     - `m` for Markdown
#     - `y` for Code
# - You can delete cells by clicking into the cell and either pressing the scissor button in the tab menu or by typing `dd`

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 0.2</b></u> <br>
#
# - Open your Week 1 Notebook.
# - Create a new Markdown cell, select it, and go into edit mode.

# %% [markdown]
# ### Working with Markdown text
#
# | Method      | Usage | Example |
# | ----------- | ----------- | ---- |
# | `#`   | 1st-level header  | see below |
# | `##`   | 2st-level header  | see below|
# | `###`   | 3st-level header  | see below |
# | `*word*`   | italics        | *word* |
# | `**word**`   | bold        | **word** |
# | `<u>word</u>` | underline | <u>word</u> |
# | left single quote marks (``)   | literal text, will format differently | `word` |
# | triple single quote marks (```)  | blocks of literal text  | see below

# %% [markdown]
# header examples:
# # 1st-level header
# ## 2nd-level header
# ### 3rd-level header
#
# blocks of literal text:
# ```
# See if you put the triple single quote marks (which are to the left of the '1' key on your keyboard) and then you type some words, and end with another set of triple single quote marks, you get this format.
# ```

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1</b></u> <br>
#
# - Make a Markdown cell that has a 1st-level heading "Week 1"
# - Add your name and today's date as regular text
# - Make a new Markdown cell, give it a 2nd-level heading "<u>Wednesday</u>, 08/20/2025"
# - Make a new Markdown cell, give it a 3nd-level heading "Exercise 1: The Python print() function"
# - Write a note to your future self about what you think that function does. Include:
#     - italic text
#     - bold text
#     - a word in a sentence using the literal text format
#     - a block of literal text

# %% [markdown]
# ### Math syntax using $\LaTeX$
#
# In Markdown cells, we can use $\LaTeX$ (LaTeX, pronounced lay-tek) to type math equations. $\LaTeX$ is a document markup language, useful for its ability to typeset mathematical formulas. For your purposes, it has two modes: paragraph and math. Paragraph mode is the default and does not need to be called. Math mode can be activated a few different ways.
#
# | Method      | Rendering | Notes  |
# | :----------- | :-----------: | :----- |
# |`In-line math goes between $f=ax$ dollar signs.`   | In-line math goes between $f=ax$ dollar signs.       | In-line math |
# |`here are words \begin{equation}
# f = ax
# \end{equation} here are words` | here are words \begin{equation} f = ax \end{equation}and more words| Goes to a new line and centers equation |
# |`more words $$...$$ more words`   | more words $$f = ax$$ more words| Goes to a new line and centers equation|

# %% [markdown]
# #### Things you can do in math mode:
# - Subscripts and superscripts
# - Grouping with curly braces
# - Fractions
# - Greek letters and special symbols
# - Roots and common functions
# - Parentheses and brackets

# %% [markdown]
# #### Other common $\LaTeX$ mathematical symbols:
# | Symbol Name      | $\LaTeX$ method | Rendering | Notes |
# | ----------- | :-----------: | :-----: | ----|
# | Fraction         | `$\frac{x}{y}$`             | $\frac{x}{y}$ | -- |
# | In-line Fraction | `$\dfrac{x}{y}$`            | $\dfrac{x}{y}$ | similar to \displaystyle with \frac |
# |Square Root|`$\sqrt{2}$`, `$\sqrt[n]{3}$`| $\sqrt{2}$ ,$\sqrt[n]{3}$| -- |
# | Greek Letters    | `$\alpha$`, `$\beta$`, `$\gamma$` | $\alpha$, $\beta$, $\gamma$ | -- |
# | Integral         |`$\int_a^b$`, `$\iint$`, `$\oint$`   | $\int_a^b$ ,$\iint$, $\oint$ | second set have \displaystyle
# | Properly sized parentheses | `$\left(\dfrac{a}{b}\right$` | $\left(\dfrac{a}{b}\right)$ | will automatically size |
# | Summations | `$\sum_{n=1}^\infty$`,`$\sum\limits_{n=1}\infty$` | $\sum_{n=1}\infty$, $\sum\limits_{n=1}\infty$ | Second set have \displaystyle
# |pi|`$\pi$`|$\pi$|--|

# %% [markdown]
# ### You can find a cheatsheet of more $\LaTeX$ notation on BrightSpace.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 2</b></u> <br>
#
# - Make a new Markdown cell with the 3nd-level header that says "Exercise 2: $\LaTeX$ math"
# - Make a new Markdown cell and on separate lines write the equation for:
#     - the cross-sectional area of a sphere
#     - the square root of a number
# - In the same cell. Within a sentence, write an example of an inline equation. This can be any equation you want (**except for the equations you've used above**)

# %% [markdown]
# ### Exercise 2: $LaTeX$ math

# %% [markdown]
# The cross sectional area of a sphere is:
# $$ A = \pi r^2 $$
# The square root of 2 is:
# $$ \sqrt{2} $$
# Energy equals mass times the speed of light squared, or $E = mc^2$.

# %% [markdown]
# ### Code cells
# Code cells can either have code or comments.
# - Code is anything written in whatever language you're using (in our case python).
# - Comments are lines of code that start with `#`. Anything on the same line as the `#` will not be run as code. Commenting your code is ESSENTIAL to help others (and your future self) understand your scripts. I also use the `#` to sometimes 'comment out' a line of code that I don't want run.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 3</b></u> <br>
#
# - Create a Markdown cell with the 3nd level header that says "Exercise 3: Code Cells"
# - Create a code cell
# - Make a comment in the first line with the following:
#     - 'This is my first code cell!'
# - On the next line enter the following in it:
#
#      `print("Hello, world!")`
#
# - Then run the cell by clicking the Run button or pressing Shift+Return

# %% [markdown]
# ## Congratulations! You've now done something everyone who learns to code has done! Please save your notebook and make sure you remember how to access it for class on Friday.
