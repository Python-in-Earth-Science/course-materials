# %% [markdown]
# ![image.png](attachment:77625c50-2588-4399-af9d-f4cabb69a421.png)

# %% [markdown]
# # Lecture Notebook 8: Count-controlled `for` loops

# %% [markdown]
# # <u>Monday</u> : 9/15
# Let's start with a review of list and dictionary methods with Exercise 1 (which was Exercise 6 in Lecture Notebook 7)

# %% [markdown]
# ### List Methods
# There are a few really useful list methods:
# | method | what it does |  changes original list? |
# |-----:|:-------|:----:|
# |`.index()` | gives you the index <br>of the item within parentheses |	❌ No |
# |`.append()` | adds item to the end | ✅ Yes |
# |`.insert()` | insert at a specific<br>position | ✅ Yes |
# |`.count()` | counts occurrences <br>of the item within parentheses |	❌ No |
# |`.remove()` | removes first occurence<br>of the item within parentheses | ✅ Yes |
# |`.pop()` | remove and return item <br>of the item's index within parentheses<br> or of last item if left blank | ✅ Yes |
# |`.sort()` | sort the list<br>in place | ✅ Yes |
# |`.reverse()` | reverses the order<br>of the items in the list | ✅ Yes |

# %% [markdown]
# <div class="alert alert-info">
#
# #### Setup your Week 5 Notebook
#
# <b><u> Exercise 1</b></u> <br>
#
#
# #### <u>Part 1</u>
# ##### Write a `for` loop that calculates and prints the percentage of the total freshwater for each class from the list
#
# 1. First, calculate the total volume using the built-in `sum()` function.
# 2. Write a `for` loop to print the percent (`freshwater_perc`) that each respective freshwater class represents.

# %%
freshwater_class = ['glaciers', 'groundwater', 'permafrost', 'lakes', 'atmosphere', 'wetlands', 'rivers']
freshwater_volume = [24100000.0, 10500000.0, 300000.0, 91000.0, 12950.0, 11500.0, 2100.0]

# %% [markdown]
# ## SIDE NOTE: the `zip()` function
# The `zip()` function allows you to iteratue through multiple lists simultaneously, pairing up elements at the same index positions.<br>
# It will stop when the shortest list runs out of items.
#
# In the example above, we want to grab the name of the class and it's associated volume, we can pair those lists and index them both at the same time by writing:
# - <span style="margin-left: 2em; color: green;">for</span> <span style="">name, volume</span> <span style="color: green;">in zip</span> <span style="">(freshwater_class, freshwater_volume):</span>

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1</b></u> <br>
#
# #### <u>Part 2</u>
# Answer in Markdown Cell:
# -  What happened to the original `freshwater_volume` list?
# -  What is the value of `freshwater_perc` outside of the loop?

# %% [markdown]
# ### Dictionary methods
# There are a few really useful dictionary methods:
# | method | what it does |
# |-----:|:-------|
# |`.keys()` | get all keys |
# |`.items()` | gives you keys and values together in a dict_item pair |
# |`.get()` | safely get a value (won't crash if key doesn't exist) |
# |`.update()` | add multiple items at once |
# |`in`<br>`not in` | check if a key exists (use with `if` statement) |
#
#
# To use them in `for` loops:<br>
# - <span style="margin-left: 2em; color: green;">for</span> <span style="">key</span> <span style="color: green;">in</span> <span style="">dictionary:</span>--> gives you **keys** only
# - <span style="margin-left: 2em; color: green;">for</span> <span style="">value</span> <span style="color: green;">in</span> <span style="">dictionary.<span style="color: blue;">values()</span>:</span>--> gives you **values** only
# - <span style="margin-left: 2em; color: green;">for</span> <span style="">key, value</span> <span style="color: green;">in</span> <span style="">dictionary.<span style="color: blue;">items()</span>:</span>--> gives you both **keys** and **values** in a data type called `dict_items()`

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1</b></u> <br>
#
# #### <u>Part 3</u>
# ##### After some research, we've discovered that there is a new reservoir! And we realized that storing things in a dictionary is probably useful...
# 3. Add a key-value pair to the `freshwater_newdict` dictionary that represents the `soil_moisture` volume of 1.65e04 km^3
# 4. Write a `for` loop that iterates over all items in the new dictionary
# 5. Add a conditional statement that alerts the reader with a warning when the newly added soil moisture is printed.

# %%
freshwater_newdict = {'glaciers': 24.1e06, 'groundwater': 10.5e06, 
            'permafrost': 3.0e5, 'lakes': 9.1e4, 'atmosphere': 1.295e4, 
              'wetlands' : 1.15e4, 'rivers': 2.1e3}

# %% [markdown]
# ### We've been using regular `for` loops that do something for each item in a collection, but what if we want to do something N times, like take 10 measurements or calculate erosion over 100 years?

# %% [markdown]
# # Count-controlled `for` loops

# %% [markdown]
# Count-controlled `for` loops will perform some task a specified number of times. <br>
#
# Where as generic`for` loops that loop through collections have this syntax:<br>
# <span style="margin-left: 2em; color: green; font-size: 18px;">for</span> <span style="font-size: 18px;">item</span> <span style="color: green; font-size: 18px;">in</span> <span style="font-size: 18px;">collection:</span><br>
# <span style="margin-left: 4em; font-size: 18px;">do things with variable</span>
#
# Count-controlled `for` loops have this syntax:<br>
# <span style="margin-left: 2em; color: green; font-size: 18px;">for</span> <span style="font-size: 18px;">i</span> <span style="color: green; font-size: 18px;">in</span> <span style="font-size: 18px;">range(n):</span><br>
# <span style="margin-left: 4em; font-size: 18px;">do things with variable</span>
#
# No conditions required!
#
# ##### **Side Note**: Remember our use of the `range()` function from Lecture Notebook 5. Look back at Exercise 1 in your Week 3 Notebook if you can't remember what this built in python function does. OR you can use `help()` to refresh your memory.

# %% [markdown]
# #### Say we want to add three to some number, but do it eight times. This loop will look like this:

# %%
base_num = 5
current_num = base_num

print(f"Original number: {current_num}")

for i in range(8):
    current_num +=3
    print(f"New number: {current_num}")

# %% [markdown]
# ### We can use count-controlled `for` loops to do things like simulate 7 days of temperature as a cold front moves through
# Let's say that we have a meteorological report that says we anticipate a temperature decrease of 1.2 $^{\circ}$C each day for the next 7 days. Begin our model by setting up 2 variables `starting_temp`, today's temperature (in $^{\circ}$C), and `cooling_rate`, the rate at which we expect the temperature to decrease (in $^{\circ}$C/day).

# %%
starting_temp = 5  # degrees C
cooling_rate = 1.2 # degrees C per day

# %% [markdown]
# ##### Remember the `range()` function?
# That's how we can easily set the number of times our count-controlled `for` loop runs.

# %%
range(7)                                    # checking to see what range(7) does

# %% [markdown]
# ##### We can set up a count-controlled `for` loop like this:

# %%
current_temp = starting_temp                                    # creating a new variable so that we don't accidentally overwrite our initial condition

print(f"On Day 0, the temperature is {current_temp}")           

for day in range(7):                                            # here, we've chosen the variable "day" and are using a range of 7.
    current_temp -= cooling_rate                                # temperature drops each day using our cooling rate
    print(f"On Day {day+1}, the temperature is {current_temp}") # NOTE: because of 0 indexing, need to add that '+1'

# %% [markdown]
# And if we wanted it to have a little more explanation...

# %% [markdown]
# <div class="alert alert-success">
#
# #### QUICK QUESTION: How would we modify this to include a conditional statement about freezing/not freezing temperatures?

# %%
# modify this code together as a class
starting_temp = 5  # degrees C
cooling_rate = 1.2 # degrees C per day
current_temp = starting_temp        # creating a new variable so that we don't accidentally overwrite our initial condition

for day in range(7):                # here, we've chosen the variable "day" and are using a range of 7.
    current_temp -= cooling_rate    # temperature drops each day using our cooling rate
    print(f"On {day+1}, the temperature is {current_temp}") # NOTE: because of 0 indexing, need to add that '+1'

# %% [markdown]
# #### One Answer:

# %%
current_temp = starting_temp                                                           # creating a new variable so that we don't accidentally overwrite our initial condition

for day in range(7):                                                                   # here, we've chosen the variable "day" and are using a range of 7.
    current_temp -= cooling_rate                                                       # temperature drops each day using our cooling rate
    if current_temp < 0:                                                               # setting up a conditional statement to printout some useful information; technically not necessary, but nice overall
        print(f"On {day+1}, the temperature is {current_temp}. That's freezing!")      # NOTE: because of 0 indexing, need to add that '+1'
    else:
        print(f"On {day+1}, the temperature is {current_temp}")                        # NOTE: because of 0 indexing, need to add that '+1'

# %% [markdown]
# ### We can also use count-controlled `for` loops to do things like find the index of a item in a nested list.
# Say we're dealing with our gully data, so:

# %%
gullies = [['Heil-Ranch-gully 1', 0.1538], 
           ['Heil-Ranch-gully2', 0.2523], 
           ['GeerCanyon', 7.325], 
           ['Central Gulch', 0.1515]
          ]

# %% [markdown]
# **What if we want to find the index of 'GeerCanyon' in this nested list?**

# %%
target_string = 'GeerCanyon'

for i in range(len(gullies)):
    if gullies[i][0] == target_string: 
        print(f"'GeerCanyon' is stored at: gullies[{i}][0]")

# %%
len(gullies)

# %% [markdown]
# Note here, I *know* from the structure of my data that 'GeerCanyon' is in the 0th index in the inner list. <br>
#
# **What if we didn't know the structure of the data?** We just knew something was listed somewhere...

# %%
target_string = 'GeerCanyon'

for i in range(len(gullies)):
    for j in range(len(gullies[i])): # loop through the inner loop first
        if gullies[i][j] == target_string:
            print(f"{target_string} is stored at: gullies[{i}][{j}]")
            break
        else:
            continue # this will continue the outer loop if the inner loop didn't break
        break # break the outer loop if inner loop broke

# %% [markdown]
# ### The new things:
# #### **nested `for` loops**
# A **nested `for` loop** is when a `for` loop is inside another `for` loop. It operatres like searching through a filing cabinet:
# - <u>the outer loop</u>: opens each drawer in the filing cabinet (one at a time)
# - <u>the inner loop</u>: looks through each file in that drawer (one at a time)<br>
# Once it's done looking through ALL files in the first drawer it moves on to the second drawer.

# %%
for i in range(3):          # Outer loop: runs 3 times
    print(f"Outer loop i = {i}")
    for j in range(2):      # Inner loop: runs 2 times FOR EACH outer loop
        print(f"  Inner loop j = {j}")
    print("  ---")

# %% [markdown]
# *Note that the inner loop completely finishes all it's iterations before the outer loop moves to its next iteration.*<br>
#
# Nested `for` loops are really useful when you have a nested list and you don't know where something is located. So it will operate like:
# 1. look at the first inner list.
# 2. look at each position within that inner list.
# 3. if it finds it, prints. If not...
# 4. move on to next inner list.
# 5. look at each position within that inner list.
# 6. etc.

# %% [markdown]
# #### **`break` & `continue`**
#
# - **break**<br>
# `break` is a keyword that immediately *exits* the current loop entirely. So if the `if` statement is true and you do end up doing something, then you don't need to continue looping through the data. I only use this when I'm looking for something in particular and I know it only occurs once in my data. OR when I'm troubleshooting (which we'll get into later). In our example, we know there's only one "GeerCanyon" so once we find it, we don't need to do anything else and we use `break` to get out of our loop.
#
# - **continue**<br>
# `continue` is a keyword that *skips* the rest of the current iteration and jumps to the next iteration. So say I'm looking for data above a threshold, this is a good way to skip the things that don't meet that threshold without using elif or else. In our example, we know that if an item is NOT "GeerCanyon", we don't want to do anything, so we use the `continue` keyword.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 2</b></u> <br>
#
# #### <u>Part 1</u>
# ##### Write a count-controlled `for` loop that models erosion and calculates elevation change over 4,000 years in the Appalachian Mountains.
# - Use an **intitial elevation** of **2037 m** (the average elevation of the Appalacians)
# - Use an **erosion rate** of **2.7e-05 m/yr** (an erosion rate derived from Be-10 measurements in the Great Smokey Mountains
# - Before you run your model, print the initial elevation with some useful description.
# - After you run your model, print the final elevation with some useful description.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 2</b></u> <br>
#
# #### <u>Part 2</u> :
# ##### Questions
# 1. Is this a lot of erosion?
# 2. What happens when you increase your erosion rate by an order of magnitude?
# 3. Using the initial erosion rate, how long would it take to erode **100 m**? Use common sense math to calculate.
# 4. What happens when you put in the answer to 3 in the `range()` function? Is there an easy solution?

# %% [markdown]
# ### Do you think erosion happens uniformly across the entire Appalachain Mountain range?
# *please say no*<br>
# Let's explore erosion at multiple sites across the Appalachians.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 2</b></u> <br>
#
# #### <u>Part 3</u> :
# ##### Write a count-controlled nested `for` loop to model erosion at four different Appalachian peaks.
# - use nested `for` loops to model **4000 years** of erosion for each peak
# - the outer loop should iterate through each mountain peak
#     - print the peak name, initial elevation, and erosion rate, rounding your print out to 2 decimal place
# - the inner loop should model erosion year by year using **each peak's specific ersion rates**
#     - print the final elevation and total erosion, rounding your print out to 1 decimal place
# - after both loops finish: determine which peak is now the tollest and which peak lost the most elevation.
#
# <span style="color: blue;"> BONUS CHALLENGE <span><br>
# - add an `if` statement that prints which peaks have "fast erosion" (erosion rate >4e-5 m/yr) when you start modeling each peak

# %%
# [peak_name, initial_elevation_in_meters, erosion_rate_m_per_year]
appalachian_peaks = [
    ['Mount Mitchell', 2037, 2.7e-05],       # Granite - slower erosion
    ['Mount Washington', 1916, 3.1e-05],     # Mixed rock - moderate erosion  
    ['Grandfather Mountain', 1800, 4.2e-05], # Quartzite - faster erosion
    ['Mount Rogers', 1746, 3.8e-05]          # Gneiss - moderate-fast erosion
]

# %% [markdown]
# ##  <span style="color: purple;"> Motivating Geoscience Problem: Glacier Mass Balance <span>
#
# Let's look at two glaciers in the French Alps: The Argentiere glacier and the Mer de Glace. (see Google Earth tab)
#
# Note that a part of each glacier is white (snow-covered) and a lower part is grey-ish (snow is melted and rocks and sediments lay on the bare surface). Glaciers only form on land where annually more snow accumulates than melts. Over a period of many years, snow becomes deep enough to form glacier ice.

# %% [markdown]
# #### Glacier Equilibrium Altitude
#
# Glaciers have an **accumulation zone**, where snow survives the summer and transforms to firn and later ice. And then, towards their toes, glaciers have an **ablation zone**, with the transition point called the **equilibrium line altitude (ELA)**.
#
# ![Screenshot%202023-09-24%20at%207.11.25%20PM.png](attachment:Screenshot%202023-09-24%20at%207.11.25%20PM.png)
#
# We have learned about temperature dependency on incoming radiation, but on Earth due to the atmosphere temperature also varies with elevation. Temperature at low elevation is generally warmer, whereas temperature at higher elevation is colder. The rate at which temperature changes with elevation is called **temperature lapse rate**.
#
# $$ lapse \: rate = 6.4   ^{\circ}C/km$$
#
# This means that at any time you can calculate where the freezing line is.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 3</b></u> <br>
#
# #### <u>Part 1</u>:
# ##### Write a program using a `for` loop that calculates temperature along a topographic gradient.
# - Assume mean annual temperature $T_0$ at sea level in the river drainage below the glacier is 15.5 $^{\circ}$C.
# - We want to calculate temperature up to 4000 m elevation.
# - Use 200 m intervals.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 3</b></u> <br>
#
# #### <u>Part 2</u>:
# ##### Find the elevation of the freezing line.
# - You could identify the elevation of the freezing line by just looking through your output, but what if you have data for every meter to sort through?
# - Find the freezing line by using a conditional statement to only start printing when you are above the freezing line altitude. Now do it a slighlty different way: create a list called `above_FLA` that you append to, and then after the loop you ask for its first item.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 3</b></u> <br>
#
# #### <u>Part 3</u>:
# ##### Last night, we found a database that records the average temprature in Chamonix for each month. Write a program that uses this data **instead** of a mean annual temperature to calculate the freezing line altitude. The monthly average temperatures in $^{\circ}$C in Chamonix:
#
# <span style="margin-left: 8em">`T_month = [-1.8,-.2,3.9, 7.4, 11.8, 15.1, 16.8, 16.4, 12.8, 9.0, 3.4, -1.1]`</span>

# %% [markdown]
# ## SIDE NOTE: Shortening printed values
#
# You might have noticed that your solutions of temperature include a lot of decimal places. To shorten it and round it, we can use some fortatting tricks using f-string syntax. We briefly discussed this in Lecture Notebook 5 (Week 3), but I wanted to give you some extra information
#
# The syntax `.1f`, `.2f`, etc. controls the number of decimal places displayed.

# %%
temperature = 2.6999999999993
print(f"Temperature: {temperature}")
print(f"Temperature: {temperature:.2f}")
print(f"Temperature: {temperature:.1f}")
print(f"Temperature: {temperature:.0f}")

# %% [markdown]
# - `.1` the number following the period controls how many decimal places to display
# - `f` the letter controls the formatting output, in this case a floating number (float)<br>
#
# Data types you can use in this syntax **for numbers**:
# | letter used | what it outputs |
# |-----:|:-------|
# |`f` | decimal number (float) |
# |`d` | whole number (int) |
# |`e` | scientific notation |
# |`%` | percentage |
# |`g` | general format (*chooses the best between regular and scientific*) |

# %% [markdown]
# References:
# A. Matmon, P.R. Bierman, J. Larsen, S. Southworth, M. Pavich, M. Caffee; Temporally and spatially uniform rates of erosion in the southern Appalachian Great Smoky Mountains. Geology 2003;; 31 (2): 155–158. doi: https://doi.org/10.1130/0091-7613(2003)031<0155:TASURO>2.0.CO;2

# %% [markdown]
# # Extra Practice
