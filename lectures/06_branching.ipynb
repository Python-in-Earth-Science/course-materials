# %% [markdown]
# ![course_header.png](attachment:c798586b-9039-4f03-8ab9-2c985d603ccc.png)

# %% [markdown]
# # Branching
#
# **Learning Objectives for Computation and Python**
#
# - Use `if-elif-else` to branch code execution
# - Use `and`, `or`, `not` keywords
# - if-statement shorthand
# - `pass` keyworkd

# %% [markdown]
# ## Branching: `if-elif-else`
#
# ### Think of branching like making decisions.
# When you wake up in the morning, you might think:
# - ***IF*** it's raining, I'll take an umbrella
# - ***ELSE***, I won't!
#
# We can do this in code and make it "decide" what to do based on different conditions.

# %% [markdown]
# ## The `if` statement
# This is the simpliest form of branching. Here's a simple example:

# %%
weather = "rainy"

if weather == "rainy":
    print("Take an umbrella!")

# %% [markdown]
# **if**<br>
# If is the keyword that starts our decision, note that when you type it and and space after, it turns green, just like 'def' did for functions.
#
# **condition statement**<br>
# Whatever follows `if` is the condition we are checking. In this case, it's `weather == "rainy"`
#
# **colon**<br>
# Just like in functions, we need this colon at the end to tell python that the following indented code should be a part of the if statement. If you don't type this, the next line won't indent automatically
#
# **indented code**<br>
# This is what happens if the condition set up on the first line is True.

# %% [markdown]
# NOTE: the condition statement can be a **conditional expression** or a variable (normally a `bool`).

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1</b></u> <br>
#
# #### Writing your first `if` statement.
#
# We want to take temperature as an input and output something given characteristics of that temperature.<br>
# (*format your weekly notebook correctly plz*)
# 1. Create a variable called `temperature` and set it equal 90 (degrees F).
# 2. Write an `if` statement such that if `temperature` is greater than 85, it prints the statement: "It is hot!"
#     - if your `if` statement is successful, it should print "It is hot!"
# 4. Change temperature to a value that would not print "It is hot!"
# 5. What happens when you run the `if` statement now?

# %% [markdown]
# ### Exercise 1

# %%
temperature = 80

#if statement
if temperature > 85:
    print("It is hot!")

# %% [markdown]
# ### But what if we want something to happen when the condition is `False`?

# %% [markdown]
# ## The `else` statement

# %% [markdown]
# It's really as simple as adding an additional key word on a new line:

# %%
weather = "sunny"

if weather == "rainy":
    print("Take an umbrella!")
else:
    print("Enjoy the sunshine!")
# Out:
# Enjoy the sunshine!

# %% [markdown]
# To use an `else` statement, you need to:
# - go to a new line after the initial `if` statement
# - ***un-indent***
# - type "else:"
#     - don't forget the colon!
# - go to another new line
# - make sure you ***indent***
# - type your indented code (i.e., what you want to happen in case the condition statement in the original `if` statement is false)
#
# In some IDEs it will automatically ***un-indent*** for you, but in others you'll have to un-indent yourself. <br>

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1 (continued)</b></u> <br>
#
# #### Writing your first `if` statement.
#
# In a new cell, copy your previous `if` statement and modify it:
#
# 5. Add an `else` statement to your `if` statement that prints "It's not so hot." if your statement is false.
# 6. Before you run your `if` statement, change your temperature value back to 95. What does your statement print when run?
# 7. Now change your temperature value to 80. What does your statement print when run?

# %% [markdown]
# ### But what if we want to have more than 2 possibilites?

# %% [markdown]
# ## The `elif` statement

# %% [markdown]
# Again, we just need one more line...

# %%
weather = "snowy"

if weather == "rainy":
    print("Take an umbrella!")
elif weather == "snowy":
    print("Wear a warm coat!")
else:
    print("Enjoy the day!")
# Out:
# Wear a warm coat!

# %% [markdown]
# The `elif` statement will always go in between the `if` and `else` statements and works the same way:
# - go to a new line after the initial `if` statement
# - ***un-indent***
# - type "elif:"
# - don't forget the colon
#     - go to another new line
# - make sure you ***indent***
# - type your indented code (i.e., what you want to happen in case the condition statement in the original `if` statement is false)

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1 (continued)</b></u> <br>
#
# #### Writing your first `if` statement.
#
# In a new cell, copy your previous `if`-`else` statement and modify it:
#
# 8. Add an `elif` statement in the correct position that prints "It is literally freezing." when the temperature is less than or equal to 32.
# 9. Change your `else` statement to print "It is neither hot nor cold."
# 10. Before your run your `if` statement, change your temperature value back to 95. What does your statement print when run?
# 11. Now change your temperature to 20. What does your statment print when run?
# 12. And finally change your temperature to 70. What does your statement print when run.

# %% [markdown]
# ### Common Mistakes to Avoid
#
# - Forgetting the colon : after conditions
# - Not indenting the code inside if/elif/else blocks
# - Using = instead of == for comparison

# %% [markdown]
# ### Some good rules of thumb:
# - Only want something to happen if a specific condition is met, **use just the `if` statement**
# - Want either one thing or another thing to happen, depending on a condition, **use the `if` and `else` statements**
# - Have a variety of things you want to happen, given a condition, **use the `if`, `elif`, and `else` statemtnes**

# %% [markdown]
# ### Sometimes, we want to have **multiple conditions** met before we do something...

# %% [markdown]
# ## The `and` & `or` keywords
# The `and` & `or` keywords can be used to test multiple conditions in a single expression.

# %% [markdown]
# #### The `and` keyword
# Use `and` when **both** conditions must be true.

# %%
weather = "rainy"
temperature = 35

if weather == "rainy" and temperature < 40:
    print("It's cold AND rainy - stay inside!")
elif weather == "rainy" and temperature >= 40:
    print("It's warm but rainy - take an umbrella!")
else:
    print("Nice weather to go out!")
# Out:
# It's cold AND rainy - stay inside!

# %% [markdown]
# #### The `or` keyword
# Use `or` when either condition can be true.

# %%
weather = "snowy"
temperature = 25

if weather == "rainy" or weather == "snowy":
    print("Bring protection from precipitation!")
elif temperature < 32:
    print("It's freezing - dress warmly!")
else:
    print("Perfect weather!")

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 2</b></u> <br>
#
# #### Writing your second `if` statement.
#
# We're going to build off of what we already have, but modify it enough that it deserves it's own exercise.
#
# ##### Create an `if` statement that depends on the variables `precip` and `temp` and uses the `and` and `or` keywords:
#
# 1. The variable `precip` should represent daily precipitation depth in inches of water and the variable `temp` should be temperature in degrees F
# 2. Here's what should happen (note directions are all phrased as if statements, but you should put this all in one linked `if-elif-else` statement:
#     - if precipitation depth is greater than 0.0 and temperature is less than 32.0, print "SNOW DAY!"
#     - if precipitation depth is greater than 0.0 and temperature is greater than 32.0, print "Rainy day."
#     - if precipitation depth is greater than 0.0 or temperature is less than 32.0, print "I'm staying indoors."
#     - if precipitation depth is less than or equal to 0.0 and temperature is greater than 90, print "It's hot, but at least it's dry."
#     - otherwise, print "Dry day, not freezing."
# 3. Using the high temperatures and precipitation amounts from following chart, plug in the values for the following days into the `precip` and `temp` variables and in a Markdown Cell, write statements that copy the ouput from your `if` statement:
#     - January 5, 2025
#     - January 9, 2025
#     - July 10, 2025
# | Year| Month | Day| High T | Low T | Precip | Snow | Snow Cover |
# |-----|-------|----|--------|-------|--------|------|------------|
# |2025 | 1  |5 |    31 |    16  |  0.03   |  0.2   |-999 |
# |2025 | 1 | 6 |    39 |    16  |  0.00   |  0.0   |   0|
# |2025 | 1 | 7 |    31 |    16  |  0.16   |  3.1   |   3|
# |2025 | 1 | 8 |    38 |     8  |  0.00   |  0.0   |   2|
# |2025 | 1 | 9 |    36 |    24  |  0.00   |  0.0   |   2|
# |2025 | 1 |10 |    43 |    13  |  0.00   |  0.0   |   1|
# |2025 | 1 | 11 |    47 |    32  |  0.00   |  0.0  |-999|
# |2025 | 7 |10  |   92  |   75 |-999.00  |   0.0   |   0 |
# |2025 | 7 |11  |   86  |   55 |-999.00  |   0.0   |   0|
# |2025 | 7 |12  |   81  |   58 |   0.20  |   0.0   |   0|
# |2025 | 7 |13  |   91  |   56 |   0.00  |   0.0   |   0|
# |2025 | 7 |14  |   93  |   65 |   0.05  |   0.0   |   0|
#
# (by the way, these data are from [https://psl.noaa.gov/boulder/data/boulderdaily.complete.txt](https://psl.noaa.gov/boulder/data/boulderdaily.complete.txt)).

# %% [markdown]
# ### Exercise 2

# %%
precip = 0.05 # daily precipitation depth in inches of water equivalent
temp = 93.0 # temperature, degrees F

if precip > 0.0 and temp < 32.0:
    print("SNOW DAY!")
elif precip > 0.0 and temp > 32.0:
    print("Rainy day")
elif precip > 0.0 or temp < 32.0:
    print("I'm staying indoors")
elif precip <=0.0 and temp > 90.0:
    print("It's hot, but at least it's dry.")
elif precip >= 0.0 and temp > 90.0:
    print("It's hot AND wet? No thank you")
else:
    print("Dry day, not freezing")
# Out:
# Rainy day

# %% [markdown]
# #### Note: -999.00 represents missing data (common in meteorological datasets). We'll learn to handle missing data in later lessons.

# %% [markdown]
# ## <span style="color: purple;">Motivating Example</span>
#
# ### <span style="color: purple;">Colorado's river gaging stations by region</span>
#
# The US Geological Survey (USGS) maintains a national network of **[stream gaging stations](https://waterdata.usgs.gov/nwis)**, where the height and flow of water is measured.
#
# ![co_gaging_stns.png](attachment:co_gaging_stns.png)

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 3</b></u> <br>
#
# Here, we will divide Colorado up into four quadrants: NE, SE, SW, and NW. We will assign gaging stations for a few of Colorado's larger rivers to these different quadrants.
#
# ```
#       105.5 W
#  ________|________ 41 N
#  |   NW  |   NE  |             > 39 N = North
#  |       |       |             < 39 N = South
# ------------------- 39 N       > 105.5 W = West
#  |   SW  |   SE  |             < 105.5 W = East
#  |       |       |
#  _________________ 37 N
#  |               |
# 109 W           102 W
# ```
# #### Write a function that takes the latitude (in degrees N) and longitude (in degrees W) of a gaging station as parameters.
# - The function should determine in which of the four quadrangles the station sits.
# - It should return a two-character string: `"NE", "SE", "NW", or "SW"`.
# - Run your code with each of the four stations below:

# %%
station_name = [
    "Arkansas River at Lamar",
    "Colorado River below Glenwood Springs",
    "San Juan at Pagosa Springs",
    "South Platte at Fort Morgan",
]

station_lat = [
    38.10579167,
    39.5549819,
    37.26552778,
    40.26840278,
]

station_lon = [
    102.6182056,
    107.337554,
    107.011,
    103.8011917,    
]

# %% [markdown]
# # Some other things...

# %% [markdown]
# ### What if we want something to happen if conditions are **NOT** met?

# %% [markdown]
# ## The `not` keyword

# %% [markdown]
# You can use the `not` operator to invert a logical expression.
# - If something is `True`, `not` makes it `False`.
# - If something is `False`, `not` makes it `True`.

# %%
weather = "sunny"

if not weather == "rainy":
    print("No need for an umbrella!")
else:
    print("Better grab that umbrella!")
# Out:
# No need for an umbrella!

# %% [markdown]
# ### What about if we need to make decisions inside decisions?
# in other words, first, this condition must be true and THEN this other conditions must be true...

# %% [markdown]
# ## Nested `if` statements
#
# You can nest `if` statements together using indentation:

# %%
weather = "rainy"
temperature = 35

if weather == "rainy":
    print("It's raining!")
    if temperature < 40:
        print("And it's cold rain - wear a coat AND take umbrella!")
    else:
        print("At least it's warm rain - just need an umbrella!")
else:
    print("No rain today!")

# %% [markdown]
# #### We could make it more complicated..

# %%
weather = "sunny"
temperature = 85
humidity = 90

if weather == "sunny":
    print("Sunny day!")
    if temperature > 80:
        print("It's hot!")
        if humidity > 85:
            print("Very humid too - stay hydrated and take breaks!")
        else:
            print("Not too humid - great for outdoor activities!")
    else:
        print("Nice mild temperature!")
else:
    if weather == "cloudy":
        print("Cloudy day")
        if temperature > 70:
            print("Still warm enough for outdoor fun!")
        else:
            print("A bit cool - bring a light jacket!")
    else:
        print("Check the specific weather conditions!")

# %% [markdown]
# For simple `if`-`else` statements, python has a shortcut..
#
# ## `if` Statement Shorthand aka the Ternary Operator!
#
# The basic syntax is:
# ```
# variable = value_if_true if condition else value_if_false
# ```

# %% [markdown]
# The long way would be...

# %%
weather = "rainy"

if weather == "rainy":
    gear = "umbrella"
else:
    gear = "sunglasses"

print(f"Bring your {gear}!")
# Out:
# Bring your umbrella!

# %% [markdown]
# The short way would be...

# %%
gear = "umbrella" if weather == "rainy" else "sunglasses"
print(f"Bring your {gear}!")
# Out:
# Bring your umbrella!

# %% [markdown]
# You can also do **ternary operations** like:
# ```
# print("A") if a > b else print("B")  <== I personally find this syntax confusing but some people like it
# ```

# %% [markdown]
# ## The `pass` keyword

# %% [markdown]
# If for some reason you don't want to take action, you can use the `pass` keyword. This works for functions too. (Usually used as a placeholder while you're writing your code.)

# %%
weather = "sunny"

# This would cause an error (empty if-block):
# if weather == "sunny":
#     # TODO: Add sunny weather code later

# This works (using pass as placeholder):
if weather == "sunny":
    pass  # TODO: Add sunny weather code later
else:
    print("Not sunny today!")

# %% [markdown]
# # Extra Practice

# %% [markdown]
# <div class="alert alert-warning">
#
# ## Extra Practice 1: Assessing Stream Gage Coverage in Colorado
# Format this the same as our normal exercises
#
# #### Part A : Basic Gage Validation
# Create a function that manages a directory of stream gages and validates their locations:
#
# Here is your starting data:
# ```
# colorado_gages = {
#     "09034500": {"name": "Colorado River below Glenwood Springs", "lat": 39.5549819, "lon": 107.337554},
#     "09143500": {"name": "Surface Creek at Cedaredge", "lat": 38.901667, "lon": 107.920556},
#     "09353800": {"name": "Los Pinos River near Ignacio", "lat":37.166111, "lon":107.910278},
#     "07124000": {"name": "Arkansas River at Lamar", "lat": 38.10579167, "lon": 102.6182056},
#     "09361500": {"name": "San Juan at Pagosa Springs", "lat": 37.26552778, "lon": 107.011},
#     "06764000": {"name": "South Platte at Fort Morgan", "lat": 40.26840278, "lon": 103.8011917},
#     "08281400": {"name": "Rio Chama above Chama", "lat":36.934944, "lon":106.554622}
# }
#
# ```
#
# #### Part B : Gage Network Analysis
# Create a function that goes through and identifies which quadrants needs more gages (i.e., those that haev less than 2)

# %%
# Part A scaffolding
def assign_quadrant_to_gages(gage_dict):
    """
    Takes a dictionary of gages and adds quadrant information.
    Returns the updated dictionary with quadrant keys added.
    """
    # Your code here - for each gage:
    # 1. Determine which quadrant it's in using if-elif-else
    # 2. Add a "quadrant" key to that gage's dictionary
    # 3. Add a "status" key: "active" if in CO bounds, "out_of_bounds" if not
    pass

# %%
# Part B scaffolding
def analyze_quadrant_coverage(gage_dict):
    """
    Analyzes how many gages are in each quadrant and identifies gaps.
    Prints a report about network coverage.
    """
    # Count gages per quadrant
    # Identify which quadrants need more gages (less than 2)
    # Print recommendations
    pass

# %% [markdown]
# ### Extra Practice 1

# %%
def assign_quadrant_to_gages(gage_dict):
    """
    Takes a dictionary of gages and adds quadrant information.
    Returns the updated dictionary with quadrant keys added.
    """
    
    # Loop through each gage in our dictionary
    for station_id in gage_dict:
        # Get the latitude and longitude for this gage
        lat = gage_dict[station_id]["lat"]
        lon = gage_dict[station_id]["lon"]
        
        # Determine quadrant using simple if-elif-else
        # North/South: 39°N is the dividing line
        # East/West: 105.5°W is the dividing line
        
        if lat >= 39.0 and lon >= 105.5:
            quadrant = "NW"
        elif lat >= 39.0 and lon < 105.5:
            quadrant = "NE"  
        elif lat < 39.0 and lon >= 105.5:
            quadrant = "SW"
        else:  # This covers lat < 39.0 and lon < 105.5
            quadrant = "SE"
        
        # Add the quadrant to this gage's information
        gage_dict[station_id]["quadrant"] = quadrant
        
        # Check if the gage is inside Colorado boundaries
        # Colorado roughly: 37°N to 41°N, 102°W to 109°W
        if lat >= 37.0 and lat <= 41.0 and lon >= 102.0 and lon <= 109.0:
            gage_dict[station_id]["status"] = "active"
        else:
            gage_dict[station_id]["status"] = "out_of_bounds"
    
    return gage_dict

# Test it with our data
colorado_gages = {
    "09034500": {"name": "Colorado River below Glenwood Springs", "lat": 39.5549819, "lon": 107.337554},
    "09143500": {"name": "Surface Creek at Cedaredge", "lat": 38.901667, "lon": 107.920556},
    "09353800": {"name": "Los Pinos River near Ignacio", "lat":37.166111, "lon":107.910278},
    "07124000": {"name": "Arkansas River at Lamar", "lat": 38.10579167, "lon": 102.6182056},
    "09361500": {"name": "San Juan at Pagosa Springs", "lat": 37.26552778, "lon": 107.011},
    "06764000": {"name": "South Platte at Fort Morgan", "lat": 40.26840278, "lon": 103.8011917},
    "08281400": {"name": "Rio Chama above Chama", "lat":36.934944, "lon":106.554622}
}

# Run the function
updated_gages = assign_quadrant_to_gages(colorado_gages)

# Print the results to see what happened
for station_id in updated_gages:
    print(f"Station: {updated_gages[station_id]['name']}")
    print(f"  Quadrant: {updated_gages[station_id]['quadrant']}")
    print(f"  Status: {updated_gages[station_id]['status']}")
    print()
# Out:
# Station: Colorado River below Glenwood Springs
#   Quadrant: NW
#   Status: active
#
# Station: Surface Creek at Cedaredge
#   Quadrant: SW
#   Status: active
#
# Station: Los Pinos River near Ignacio
#   Quadrant: SW
#   Status: active
#
# Station: Arkansas River at Lamar
#   Quadrant: SE
#   Status: active
#
# Station: San Juan at Pagosa Springs
#   Quadrant: SW
#   Status: active
#
# Station: South Platte at Fort Morgan
#   Quadrant: NE
#   Status: active
#
# Station: Rio Chama above Chama
#   Quadrant: SW
#   Status: out_of_bounds

# %%
def analyze_quadrant_coverage(gage_dict):
    """
    Count how many gages are in each quadrant and report on coverage.
    """
    
    # Start with zero gages in each quadrant
    nw_count = 0
    ne_count = 0
    sw_count = 0
    se_count = 0
    
    # Count gages in each quadrant
    for station_id in gage_dict:
        quadrant = gage_dict[station_id]["quadrant"]
        
        if quadrant == "NW":
            nw_count = nw_count + 1
        elif quadrant == "NE":
            ne_count = ne_count + 1
        elif quadrant == "SW":
            sw_count = sw_count + 1
        elif quadrant == "SE":
            se_count = se_count + 1
    
    # Print the results
    print("GAGE COUNT BY QUADRANT:")
    print(f"Northwest (NW): {nw_count} gages")
    print(f"Northeast (NE): {ne_count} gages") 
    print(f"Southwest (SW): {sw_count} gages")
    print(f"Southeast (SE): {se_count} gages")
    print()
    
    # Check for gaps (quadrants with no gages)
    print("COVERAGE ANALYSIS:")
    
    if nw_count == 0:
        print("No gages in Northwest quadrant!")
    elif nw_count == 1:
        print("Northwest has 1 gage (could use more)")
    else:
        print("Northwest has good coverage")
    
    if ne_count == 0:
        print("No gages in Northeast quadrant!")
    elif ne_count == 1:
        print("Northeast has 1 gage (could use more)")
    else:
        print("Northeast has good coverage")
        
    if sw_count == 0:
        print("No gages in Southwest quadrant!")
    elif sw_count == 1:
        print("Southwest has 1 gage (could use more)")
    else:
        print("Southwest has good coverage")
        
    if se_count == 0:
        print("No gages in Southeast quadrant!")
    elif se_count == 1:
        print("Southeast has 1 gage (could use more)")
    else:
        print("Southeast has good coverage")

# Test the analysis
analyze_quadrant_coverage(updated_gages)
# Out:
# GAGE COUNT BY QUADRANT:
# Northwest (NW): 1 gages
# Northeast (NE): 1 gages
# Southwest (SW): 4 gages
# Southeast (SE): 1 gages
#
# COVERAGE ANALYSIS:
# Northwest has 1 gage (could use more)
# Northeast has 1 gage (could use more)
# Southwest has good coverage
# Southeast has 1 gage (could use more)

# %% [markdown]
# <div class="alert alert-warning">
#
# ### Extra Practice 2: Weather Advisory System
#
# #### Create a function to check weather station data for errors and classify data quality.
#
# Weather station data is typically given with:
# - temperature in Celcius
# - relative humidity as a %
# - atmospheric pressure in millibars
# - wind speed in m/s
# - daily precipitation depth in mm
#
# Use the following data:
# ```
# weather_stations = [
#     {"name": "Denver", "temp_c": 25, "humidity": 45, "pressure_mb": 1013, "wind_speed_mps": 5, "precipitation_mm": 0},
#     {"name": "Arctic Station", "temp_c": -45, "humidity": 90, "pressure_mb": 1025, "wind_speed_mps": 15, "precipitation_mm": 2},
#     {"name": "Faulty Sensor", "temp_c": 150, "humidity": 120, "pressure_mb": 500, "wind_speed_mps": 200, "precipitation_mm": -5},
# ]
# ```
#
# Your function should act as a quality control expert in which you decide if the data is:
# - completely impossible (invalid)
# - weird, but possible (suspicious)
# - good (valid)
#
# Please use nested `if` statements and multiple conditions with `and`/`or`

# %%
def validate_weather_data(station_data):
    """
    Check weather station data for errors and classify data quality.
    
    station_data = {
        "temp_c": temperature in Celsius,
        "humidity": relative humidity %,
        "pressure_mb": atmospheric pressure in millibars,
        "wind_speed_mps": wind speed in m/s,
        "precipitation_mm": daily precip in mm
    }
    
    Flag as "INVALID" if:
    - Temperature outside -80°C to 60°C
    - Humidity outside 0-100%
    - Pressure outside 800-1100 mb
    - Wind speed > 100 m/s
    - Precipitation < 0
    
    Flag as "SUSPICIOUS" if:
    - Extreme but possible values
    - Inconsistent combinations (e.g., 100% humidity but no precipitation)
    
    Otherwise "VALID"
    """
    pass

# %% [markdown]
# ### Extra Practice 2

# %%
def validate_weather_data(station_data):
    """
    Check weather station data for errors and classify data quality.
    """
    
    # Get the values from the dictionary
    temp = station_data["temp_c"]
    humidity = station_data["humidity"]
    pressure = station_data["pressure_mb"]
    wind_speed = station_data["wind_speed_mps"]
    precipitation = station_data["precipitation_mm"]
    
    # First check: Are any values completely impossible?
    if temp < -80 or temp > 60:
        return "INVALID"
    elif humidity < 0 or humidity > 100:
        return "INVALID"
    elif pressure < 800 or pressure > 1100:
        return "INVALID"
    elif wind_speed < 0 or wind_speed > 100:
        return "INVALID"
    elif precipitation < 0:
        return "INVALID"
    else:
        # Check for suspicious combinations using nested if-statements
        if temp > 35:  # If it's very hot...
            if humidity > 95 and precipitation == 0:
                return "SUSPICIOUS"
        
        if temp < -60 or temp > 50:
            return "SUSPICIOUS"
        elif pressure < 850 or pressure > 1050:
            return "SUSPICIOUS"
        elif wind_speed > 50:
            return "SUSPICIOUS"
        else:
            return "VALID"


# Your data
weather_stations = [
    {"name": "Denver", "temp_c": 25, "humidity": 45, "pressure_mb": 1013, "wind_speed_mps": 5, "precipitation_mm": 0},
    {"name": "Arctic Station", "temp_c": -45, "humidity": 90, "pressure_mb": 1025, "wind_speed_mps": 15, "precipitation_mm": 2},
    {"name": "Faulty Sensor", "temp_c": 150, "humidity": 120, "pressure_mb": 500, "wind_speed_mps": 200, "precipitation_mm": -5},
]

# Test Station 0 (Denver)
print(f"=== {weather_stations[0]['name']} ===")
result_0 = validate_weather_data(weather_stations[0])
print(f"Temperature: {weather_stations[0]['temp_c']}°C")
print(f"Humidity: {weather_stations[0]['humidity']}%")
print(f"Result: {result_0}")
print()

# Test Station 1 (Arctic Station)
print(f"=== {weather_stations[1]['name']} ===")
result_1 = validate_weather_data(weather_stations[1])
print(f"Temperature: {weather_stations[1]['temp_c']}°C")
print(f"Humidity: {weather_stations[1]['humidity']}%")
print(f"Result: {result_1}")
print()

# Test Station 2 (Faulty Sensor)
print(f"=== {weather_stations[2]['name']} ===")
result_2 = validate_weather_data(weather_stations[2])
print(f"Temperature: {weather_stations[2]['temp_c']}°C")
print(f"Humidity: {weather_stations[2]['humidity']}%")
print(f"Result: {result_2}")
print()
