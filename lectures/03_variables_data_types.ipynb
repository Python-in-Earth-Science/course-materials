# %% [markdown]
# ![course_header.png](attachment:a35336fc-b886-493b-9fe6-af031f741f42.png)

# %% [markdown]
# # Variables and data types
#
#
# - Goals:
#   - Use the assignment operator to create or update a variable
#   - Define dynamicically typed programming language
#   - Identify the basic data types in Python
#   - Determine the type of a variable
#   - Convert between basic data types
#   - Use `%whos` to list the variables stored in the memory of the python kernel

# %% [markdown]
# ## Variables
#
# A **variable** is a reserved space in the computer that holds data of a given **type** and accessed via a name that the programmer assigns.
#
# Example:
#
# `earth_radius = 6370    ` (make memory space big enough; fill w/ binary version of 6370)
#
# `print(earth_radius)    ` (fetch value at that memory space and display in human-readable form)

# %% [markdown]
# ## The assignment operator `=`
#
# - **Not** a statement of equality!
#
# - **Assigns** the value on the right to the variable on the left
#   - *(the variable "gets" the value)*
#
# - **Defines** the variable if it does not already exist
#
# - When a new variable is defined, Python **allocates** a piece of computer memory to contain its value, encoded in binary

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 1</b></u> <br>
#
# - Format your new InClass notebook correctly:
#     - 1st level heading: Week 2
#     - plain text of your name
#     - 2nd level heading underlined: Monday with today's date
#     - 3rd level heading: Exercise 1
# - In one Code cell, use Python operators to calculate and print the solar energy influx at the following different time periods by creating new variables for each solar constant and storing the energy in in new variables for each time period:
# | Time      | Age | $S_0$ |
# | ----------- | ----------- | ---- |
# | Today   | 2025 | $ \approx 1360$ W/m$^2$ |
# | Early Archean   | 4 Ga  | $\approx 970$ W/m$^2$ |
# | Early Paleozoic   | 430 Ga  | $ \approx 1320$ W/m$^2$|
# | The future  | A billion years from now  | $ \approx 1500$ W/m$^2$|
# - After each calculation, include a use of the `print()` function that will print the output with an appropriate description.
#
#
# **Remember**
# - You already have code from last week that calculates this. Feel free to copy and paste.

# %% [markdown]
# See if you can work out the sequence of operations in your code, and especially the line that performs a calculation and assigns the result to a new variable called `earth_power_input`. In what order do you think the operations are processed?

# %% [markdown]
# ## Redefing variables
#
# When you assign a value to an existing variable, its previous value is erased.
#
# If the value assigned is of a different type than the original variable, the variable is redefined to the new type.

# %%
r_e = 6378 # radius of Earth
A_c = 3.14*r_e**2 # surface area of Earth that faces the sun

# you could run this cell once with the first S_0 (i.e., second is commented out)
# and then again with the second one (i.e., first is commented out) and S_0 will be overwritten
S_0 = 1360 # solar constant v1
#S_0 = 1500 # solar constant v2

P = S_0*(1-a)*A_c
print('Now:', P_now)

# %% [markdown]
# ## Variable types
# - Every variable has a **type**
# - Many programming languages are *statically typed*
#   - the programmer has to declare the type of each variable
# - Python is a *dynamically typed* language
#   - When a variable is defined, Python matches the variable type with the value that is assigned to it.
# - <u>Some Rules</u>:
#     - Variables assigned a number without a decimal point are typed as **int** *(integer)*
#     - Variables assigned a number with a decimal point, or using exponential notation, are typed as **float** *(floating point number)*
#     - Variables assigned a sequence of characters between `""` or `''` are typed as **string**
# - The `type()` function returns the type of a variable

# %%
# variable examples
mohs_hardness_number = 7
mass_density = 2650.0 # in kg/m3
mineral_name = "quartz" 

# now print those
print(type(mohs_hardness_number))
print(type(mass_density))
print(type(mineral_name))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 2</b></u> <br>
#
# - Format this exercise correctly with a third level header.
# - Then create a code cell or cells to complete the following:
#     - pick one of the planets listed below (Mercury, Venus, Earth, Mars)
#     - declare and assign a string variable for the planet's name
#     - declare and assign an integer variable for the planet's number (Mercury is 1, Earth is 3, etc.)
#     - declare and assign a floating point variable for the planet's solar irradiance
#     - print out the `type()` of each to verify that the variable is of the type you intended
#
# | Planet      | Solar irradiance (W/m$^2$) | Albedo | Radius (km$^2$) |
# |-------------|----------------------------|--------|-----------------|
# | Mercury (1) | 9,083 | 0.068 | 2,440 |
# | Venus (2)   | 2,636 | 0.77 | 6,050 |
# | Earth (3)   | 1,360 | 0.31 | 6,370 |
# | Mars (4)    | 586   | 0.25 | 3,390 |

# %% [markdown]
# ### Type casting
#
# No, not the Hollywood habit. This is about converting variables from one type to another. Examples:
#
# - `int()` converts a value to an integer
# - `float()` converts a value to a float
# - `str()` converts a value to a string

# %%
# Some examples
print(int(3.1415))
print(float(5))
print(str(6.03e22))
# Out:
# 3
# 5.0
# 6.03e+22

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 3</b></u> <br>
#
# - Format this exercise correctly with a third level header.
# - Then create a code cell or cells to complete the following:
#     - Try to cast the planet number to a float. Print the output. What happens?
#     - Try to cast the solar irradiance to an integer. Print the output. What happens?
#     - Try to cast either one to a string. Print the output. What happens?
#     - Try to cast the planet name to a float or an integer. What happens?

# %% [markdown]
# ## Assignment versus comparison
#
# `=` is the **assignment** operator, and `==` is a **comparison** (in particular, equality) operator.
#
# A comparison operator compares values on the left and right, and returns a special quantity: either `True` or `False`
#
# Examples:
#
# - `2 = 1 + 1` <= generates an error
# - `2 == 1 + 1` <= produces a result
# - `result = 2 == 1 + 1` <= stores the result in a variable called `result`
# - `type(result)` <= the result has type `bool`

# %%
#2=1+1
result = 2 == 1 + 1
print(result)
type(result)
# Out:
# True
# bool

# %% [markdown]
# ## `bool`
#
# A **boolean** variable, of type `bool`, can have only one of two possible values: `True` or `False`

# %% [markdown]
# ## Comparison operators
#
# - A **comparison operator** compares two values and returns either `True` or `False`
# - Python comparison operators:
#   - Equal to `==`
#   - Unequal to `!=`
#   - Greater than `>`
#   - Less than `<`
#   - Greater than or equal to `>=`
#   - Less than or equal to `<=`
# - A boolean (`bool`) variable can be (only) `True` or `False`

# %%
print(5!=5)
print(5!=10)
print(6>3)
print(6<3)
print(6<=3)
print(6>=6)
# Out:
# False
# True
# True
# False
# False
# True

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 4</b></u> <br>
#
# - Format this exercise correctly with a third level header.
# - Then create a code cell or cells to complete the following:
#     - Use comparison operators to test whether:
#         - Mercury's solar irradiance is greater than Earth's
#         - Earth's irradiance is less than or equal to Venus' irradiance
#         - Mars and Earth have equal solar irradiance.
#     - Create a boolean variable that records whether Earth's solar irradiance (in W/$m^2$) equals 1360.

# %% [markdown]
# ## `%whos` on first?
#
# In a Jupyter notebook (or in an IPython console, which we haven't met yet), you can get a list of the current variables using the use the [magic command](https://ipython.readthedocs.io/en/stable/interactive/magics.html) `%whos`.
#
# This is a Jupyter/IPython command, NOT a Python keyword.

# %%
# %whos
# Out:
# Variable               Type     Data/Info
# -----------------------------------------
# A_c                    float    127731695.76
# P0                     float    1.2129571563199998e+17
# P_arch                 float    86729821421.04001
# P_fut                  float    134118280548.0
# P_now                  float    121600574363.51999
# P_paleo                float    118024086882.23999
# S0_4bil                int      970
# S0_now                 int      1360
# S_arch                 int      970
# S_fut                  int      1500
# S_now                  int      1360
# S_paleo                int      1320
# a                      float    0.3
# mass_density           float    2650.0
# mineral_name           str      quartz
# mohs_hardness_number   int      7
# r                      float    6370000.0
# r_e                    int      6378
# result                 bool     True

# %% [markdown]
# ## Restarting the Jupyter notebook kernel
#
# The Jupyter **kernel** is basically the notebook's operating system.
#
# It includes the Python **interpreter**: the program that reads and executes your Python code.
#
# When you **restart the kernel**, any existing variables are deleted.

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 5</b></u> <br>
#
# - Format this exercise correctly with a third level header.
# - In a code cell, run `%whos`
# - copy the output into a Markdown cell
# - From the **Kernal** menu select **Restart and Run All**
# - Run `%whos` again and make a note in the Markdown cell about what changed.

# %% [markdown]
# ## Working with strings
#
# - Define a string using single or double quotes: `mystr = "Earth is (almost) round"`
# - Find the length of a string with the `len()` function: `print(len(mystr))`
# - **Concatenate** strings with the `+` operator: `geodesy_fact = mystr + " but not quite"`

# %%
mystr = "Earth is (almost) round"
print(len(mystr))

geodesy_fact=mystr + ", but not quite"

print(geodesy_fact)
# Out:
# 23
# Earth is (almost) round, but not quite

# %% [markdown]
# ## String indexing
#
# - Python uses zero-based indexing.
# - If were were to store the string 'abcd' in the variable `letters`, the indices of the letters would be:
#     - a = 0
#     - b = 1
#     - c = 2
#     - d = 3
# - We can use this to grab specific characters from our string.
# - To grab the 'b' of our string above, we can use square brackets `[ ]`
#     - `letters[1]`, which will give us `b`
# - To grab **slices** of the string, we can use the colon, like so:
#     - to grab the first 2 characters, we'd type `letters[:2]`
#         - this will grab indices 0 and 1; this is called 'exclusive'. In other words, it grabs up to, but not including the 2nd index.
#         - if we wanted to include the 2nd index, we'd type `letters[:3]`
#     - to grab the last 2 charcters, we'd type `letters[2:]`
#         - this will grab indices 2 and 3; this is called 'inclusive' In other words, starts at the index listed and grabs everything else through the end, including the end.
#     - to grab a specific range of characters, we'd type `letters[1:3]`
#         - this will be exclusive on the left and inclusive on the right, so that will grab b & c, but not d

# %% [markdown]
# <div class="alert alert-info">
# <b><u> Exercise 6</b></u> <br>
#
# - Format this exercise correctly with a third level header.
# - Then create a code cell or cells to complete the following:
#     - Retrieve the 5th character of the string stored in the variable `geodesy_fact`
#         - Should be the 4th index
#     - Retrieve the the first 23 indices of `geodesy_fact`
#     - Retrieve the last 23 indices of `geodesy_fact`
#     - Retrieve the 23rd through the 26th characters of `geodesy_fact`
#         - don't forget how indices and characters work!

# %% [markdown]
# ## Splitting a string into words
#
# `print(geodesy_fact.split())`
#
# - `split()` is an example of a special kind of function called a **method** that acts on a particular **object**
# - Returns a data type called a **list** containing the individual words
# - By default, `split()` detects words based on spaces (you can change this)
# - We'll meet **lists** next week

# %%
print(geodesy_fact.split())
# Out:
# ['Earth', 'is', '(almost)', 'round,', 'but', 'not', 'quite']

# %% [markdown]
# ## Review
#
# - Use the assignment operator to create or update a variable
# - Define dynamicically typed programming language
# - Identify the basic data types in Python
# - Determine the type of a variable
# - Convert between basic data types by typecasting
# - Use `%whos` to list the variables stored in the memory of the python kernel
# - Clear variables by re-starting the kernel
# - Parse and manipulate strings
