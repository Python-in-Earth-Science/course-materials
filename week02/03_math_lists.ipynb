# %% [markdown]
# # Lecture 03 — Functions You Didn't Write & Lists
# ### EES 3350/5350 · Python in Earth Science · Wednesday, September 2, 2026
#
# **Learning objectives for today**
# - import and use functions from the `math` module
# - understand a function as reusable code someone else wrote (you'll be writing your own next week!)
# - create a list and understand list syntax
# - index into a list, including negative indices
# - slice a list to pull out a range of elements

# %% [markdown]
# ---
# ## 🌡️ Warm-Up (TopHat — 2 minutes)
#
# Today's warm-up is a quick check on last week's material — answer within the first few minutes for credit.

# %% [markdown]
# ---
# <div class="alert alert-danger">
#
# ### Have you made a copy of this file??
# Make sure you've followed our typical workflow!
#
#         Open from `course-materials/` → rename → copy to your personal folder → work there.

# %% [markdown]
# ---
# # The main ways you'll store, reference, and operate on data within a Python script are variables and object.s Today, we'll add two new tools to that toolkit: functions someone else already wrote and lists.
# ---

# %% [markdown]
# # Part 1 — Functions You Didn't Write: the `math` module
# In Lab 1, you calculated Earth's blackbody temperature by hand, including hardcoding a value for $\pi$:
# ```python
# pi = 3.14159
# ```
# Someone already wrote a function for that, though! Python's `math` module bundles together dozens of useful constants and functions so you don't have to hardcode them yourself.

# %%
import math # you always have to import before you use a module

# %% [markdown]
# Let's compare `math.pi` to the hardcoded value you used in Lab 1:

# %%
print("Your Lab 1 value:", 3.14159)
print("math.pi value:", math.pi)

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** `math.pi` carries far more decimal digits than the `3.14159` you hardcoded in Lab 1. Small rounding differences like this are one reason your calculated values won't always match a textbook or NASA value exactly.

# %% [markdown]
# The `math` module also has functions like `math.sqrt()` (square root) and `math.pow()` (exponentiation) that do the same job as `**0.5` or `**`, just with clearer names.

# %%
print(math.sqrt(16))
print(math.pow(2,3))

# %% [markdown]
# ### Some useful `math` module functions
#
# The `math` module has a ton of useful functions, like
# | Function | Description | Example |
# |---|---|---|
# | `math.pi` | π, to 15 decimal places (attribute — no parentheses) | `math.pi` → `3.14159...` |
# | `math.e` | Euler's number (attribute — no parentheses) | `math.e` → `2.71828...` |
# | `math.sqrt(x)` | Square root of x | `math.sqrt(16)` → `4.0` |
# | `math.pow(x, y)` | x raised to the power y | `math.pow(2, 3)` → `8.0` |
# | `math.floor(x)` | Round down to the nearest integer | `math.floor(4.9)` → `4` |
# | `math.ceil(x)` | Round up to the nearest integer | `math.ceil(4.1)` → `5` |
# | `math.log10(x)` | Base-10 logarithm of x | `math.log10(100)` → `2.0` |
# | `math.radians(x)` | Convert degrees to radians | `math.radians(180)` → `3.14159...` |
#
# This is only a slice — the full list, including trig functions and more, lives on the Cheat Sheets page under the **Math** tab.

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** You don't have to memorize every frunction in a module, in a code cell, type `math.` and press **Tab**. Jupyter will show you every functino and constant `math` has available.

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Question 1:</b>
#
# What are some things in the `math` module you think would be useful? Feel free to add a code cell after this one to use *Tab* to expore the `math` module.

# %% [markdown]
# > Your answer here.

# %% [markdown]
# ### What's up with the `.` you put after `math`?
#
# Recall from Lecture 1 that in Python, everything is an **object** and every object carries it's own **attributes** (data attached it, sometimes called metadata) and **methods** (functions attached to it). the dot (`.`) is how you reach into an object and grab one of those.
# - `math.pi` is an **attribute**, a value stored inside the `math` module. No parentheses, because you're not *calling* anything, just retrieving a value.
# - `math.sqrt()` is a **method**, a functino that belongs to the `math` module. It needs partentheses because you're *calling* it, the same way you call `print()`.
#
# #### You've actually been using dot syntax since Lecture 1! Everytime you wronte `os.getcwd()` or `os.listdir()`, those are mtehods too.

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 1
#
# **Rewrite Lab 1's blackbody temperature calculation using `math.pi` and `math.pow()` instead of hardcoded values.**
#
# Recall from Eq. 3 from Lab 1:$$T = \left(\frac{\Omega}{4\sigma}\right)^{1/4}$$
#
# Use `solar_constant = 1372` and `stef_boltz = 5.67e-8`.
#
# </div>

# %%
# your code here
solar_constant = 1372
stef_boltz = 5.67e-8

T = ______________
print(T)

# %% [markdown]
# Let's see what `math.floor()` and `math.ceil()` do.

# %%
print(math.floor(254.58))
print(math.ceil(254.58))

# %% [markdown]
# - `math.floor()` will round **down** to the nearest whole number
# - `math.ceil()` will round **up** to the nearest whole number

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 2
#
# Your Exercise 1 answer for Earth's blackbody temperature should have been about 254.58 K. **Use `math.floor()` and `math.ceil()` to find the whole degree range it falls between**
#
# </div>

# %%
# your answer here
print(math.floor(_____))
print(math.ceil(______))

# %% [markdown]
# ### A function *you* write looks like this
# The `math` functions above were written by someone else. But starting next week, you'll be writing your own. And they're not as mysterious as they might seem!
#
# **Remember how many times you did the same calculation in the lab?** Instead of repeating the WHOLE calculation each time, we can write a function to quickly do this calculation whenver we want. Here's teh exact blackbody temperature calculation from Lab 1 (Eq. 8, with albedo), wrapped up as a function:

# %%
def blackbody_temp(S, a, stef_boltz=5.67e-8):
    """
    Predict a planet's blackbody surface temperature (K) from its solar constant (S) and albedo (a).
    """
    T = ((1 - a) * S / (4 * stef_boltz)) ** (1/4)
    return T

# %% [markdown]
# - `def` starts a function definition, followed by a name you choose (`blackbody_temp`) and the **parameters** it needs in parentheses — the inputs the function expects each time you use it.
# - Everything indented underneath is the function's *body* — the steps it runs.
# - `return` sends a value back out, the same way `math.sqrt(16)` hands you back `4.0`.
#
# For now, don't worry about writing your own — just notice that this is nothing more than Eq. 8 from Lab 1, given a name.

# %% [markdown]
# ##### To a custom function, you'll need to "call the function" by writing out whatever was defined in blue in the first line of your function definition.
# In our case, that'd be:
# - `blackbody_temp`
# ##### Then you need to provide it inputs to assign to it's parameters based on whatever is within the parentheses in that first line.
# In our case, we need:
# - `S` (a solar constant)
# - `a` (the abedo)
# - `stef_boltz` (the Stefan-Boltzmann constant)
#
# If you look at the first line of our function, you'll see that there is already a *default* value provided for `stef_boltz`, so unless we want to change that value, we don't need to provide that input parameter.
#
# #### Here's what it looks like to use the custom function `blackbody_temp` to calculate the temperature of Earth and Mars:

# %%
T_earth = blackbody_temp(S=1372, a=0.31)
T_mars = blackbody_temp(S=586, a=0.25)

print(T_earth)
print(T_mars)

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** In Lab 1, you rewrote this same equation by hand for Earth, then Mars, then Mars again at perihelion and aphelion — four nearly identical blocks of code. A function lets you write the equation once and reuse it as many times as you need, just by changing the inputs.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Part 2 — Lists
# So far, every variable you've created has stored a single value. What if you wanted to store several related values under one name, like the solar irradience of four different planets?
# > **Lists** are Python's way of storing multiple values in a single variable. They are defined with square brackets, with commas between items: `a = [4.-, 2.5, 5.1]`. Lists are **mutable**, meaning you can change what's inside them after you create them.
#
# We are going to use planet data for the rest of this lecture, pulling in Mercury and Venus alongside Earth and Mars values from Lab 1.
#
# | Planet      | Solar irradiance (W/m²) | Albedo | Radius (km) |
# |-------------|--------------------------|--------|-------------|
# | Mercury     | 9,083                    | 0.068  | 2,440       |
# | Venus       | 2,636                    | 0.77   | 6,050       |
# | Earth       | 1,360                    | 0.31   | 6,370       |
# | Mars        | 586                      | 0.25   | 3,390       |
#
# We can create lists of this data like this:

# %%
planet_names = ["Mercury", "Venus", "Earth", "Mars"]
solar_irradiance = [9083, 2636, 1360, 586] # W/m^2
albedo = [0.068, 0.77, 0.31, 0.25]
radius_km = [2440, 6050, 6370, 3390]

# %% [markdown]
# And then we can print the whole list like this:

# %%
print(planet_names)

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** Notice that `planet_names`, `solar_irradiance`, `albedo`, and `radius_km` are all in the same order — Mercury is always first, Mars is always last. Keeping related lists in the same order like this (called **parallel lists**) is what lets you look up matching information across them. Later in the course, we'll use tools like dictionaries and DataFrames that keep this pairing more explicit.
# </div>

# %% [markdown]
# Let's confirm these are lists using a function you already know: `type()`

# %%
print(type(planet_names))

# %% [markdown]
# ##### Woo! That variable points to a list!
#
# What if we want to access one item from that list? that's where indexing comes in...
#
# ### Indexing
#
# In Python, the **first item in a list has index 0**, not 1. To get an item out of a list, put its index in square brackets after the list name.

# %%
print(planet_names[0]) # first planet in list has index 0
print(planet_names[1]) # second planet in list has index 1

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** **This is what we call "`zero indexing`".** Zero-based indexing feels backwards at first — just remember that `list[0]` means "the first step from the start," not "item number one." It becomes automatic with practice.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Question 2:</b>
#
# What planet is stored at `radius_km[1]`? Predict the answer, then check it by running a cell.

# %% [markdown]
# > your answer here

# %%
radius_km[1]

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** Try to index past the end of a list — e.g. `planet_names[10]` — and Python raises an `IndexError`. It's a new error type, similar in spirit to `NameError` and `ValueError`: it means you asked Python for something that isn't there.
# </div>

# %% [markdown]
# ### Negative Indexing
# You can also index from the **end** of a list using negative numbers. `list[-1]` is always the last item, no matter how long the list is.

# %%
print(planet_names[-1]) # last planet
print(planet_names[-2]) # second to last planet

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** Negative indexing is especially handy when you don't know (or don't want to count) how long a list is — `list[-1]` always works, whether the list has 4 items or 4,000.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 3
#
# Use indexing to print the **albedo of Mars** two different ways: once using a positive index, and once using a negative index.
# </div>

# %%
# positive index
print(______________)

# negative index
print(______________)

# %% [markdown]
# ### Slicing
# Sometimes you want more than one item, but not the whole lsit. **Slicing** lets you pull out a range using `list[start:stop]`.

# %%
print(planet_names)
print(planet_names[0:2])

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Question 3:</b>
#
# Why do you think this only printed out the first two names, not the names from indices 0, 1, and 2?

# %% [markdown]
# > your answer here

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 4
#
# The **terrestrial planets** are the four rocky, Earth-like planets closest to the Sun — conveniently, all four planets in our list! **Use slicing to select just Mercury and Venus, the two innermost terrestrial planets.**
# </div>

# %%
# your code here
innermost = ______________
print(innermost)

# %% [markdown]
# <div class="alert alert-success">
#
# **Tip:** You can leave out the start or stop number in a slice — <code>list[:2]</code> means "from the beginning up to (not including) index 2," and <code>list[2:]</code> means "from index 2 to the end."
#
# </div>
# <div class="alert alert-info">
#
# ### Exercise 5
#
# Use the above shortcut to print every planet <b>except</b> Mercury.
#
# </div>

# %%
# your code here

# %% [markdown]
# ### Slicing with a step
# There's a third number you can add to a slice: `list[start:stop:step]`. The `step` controls how many items to skip each time. A step of `2` takes every other item.

# %%
print(planet_names)
print(planet_names[::2]) # print every other planet starting from the beginning

# %% [markdown]
# ##### Note how we left out `start` and `stop` but keep the step (`list[::2]` means "the whole list, but skip through it." This is also how you referse a list:
# - `list[::-1]` uses a step of `-1`, walking backward from the end.

# %%
print(planet_names[::-1])

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 6
#
# Use step slicing to print **every other** value in `radius_km`, starting from Venus rather than Mercury.
#
# </div>

# %%
# your code here

# %% [markdown]
# #### QUICK CHECK: predict before you run
# Before running the cell below, discuss with your neighbor what each line will print.

# %% [markdown]
# > your answers here

# %%
print(planet_names[1])
print(planet_names[-2])
print(planet_names[1:3])
print(planet_names[:2])
print(planet_names[::-1])

# %% [markdown]
# <div class="alert alert-info">
#
# ### Exercise 7
#
# Use `blackbody_temp()` together with list indexing to calculate the predicted blackbody temperature of **Venus** — no hardcoded numbers. Pull everything from `planet_names`, `solar_irradiance`, and `albedo`.
# </div>

# %%
# your code here
T_venus = blackbody_temp(S=______________, a=______________)
print(f"{______________}'s predicted blackbody temperature is {T_venus:.2f} K.")
